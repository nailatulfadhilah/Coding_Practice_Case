# %% [markdown]
# # DVD Rental Analysis
# The analysis begins with inputting the database and understanding the schema of the database. The database can be downloaded at <a href="https://www.postgresqltutorial.com/postgresql-sample-database/" target="_blank">this link</a>. Here is a scheme that helps in understanding the ERM (Entity Relationship Model):
# ![dvd-rental-sample-database-diagram.png](attachment:dvd-rental-sample-database-diagram.png)

# %%
#Install the libraries that will be used
# !pip install ipython-sql
# !pip install sqlalchemy
# !pip install psycopg2

# %%
#load ipython-sql
# %load_ext sql

# %%
#Import function create_engine() from sqlalchemy because we only need that
from sqlalchemy import create_engine

# %%
#Connect ipython-sql to database
# %sql postgresql://postgres:***@localhost/DVDrental

# %%
#Called engine using the create_engine() function
engine = create_engine('postgresql://postgres:***@localhost/DVDrental')

# %% [markdown]
# ## Question 1
# Recommendations the film about 'astronaut'

# %%
# %%sql
#
# SELECT *
#     FROM film
#     WHERE fulltext @@ to_tsquery('astronaut');
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 78 rows affected.
# [(16, 'Alley Evolution', 'A Fast-Paced Drama of a Robot And a Composer who must Battle a Astronaut in New Orleans', 2006, 1, 6, Decimal('2.99'), 180, Decimal('23.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries'], "'alley':1 'astronaut':18 'battl':16 'compos':13 'drama':7 'evolut':2 'fast':5 'fast-pac':4 'must':15 'new':20 'orlean':21 'pace':6 'robot':10"),
#  (21, 'American Circus', 'A Insightful Drama of a Girl And a Astronaut who must Face a Database Administrator in A Shark Tank', 2006, 1, 3, Decimal('4.99'), 129, Decimal('17.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Behind the Scenes'], "'administr':17 'american':1 'astronaut':11 'circus':2 'databas':16 'drama':5 'face':14 'girl':8 'insight':4 'must':13 'shark':20 'tank':21"),
#  (25, 'Angels Life', 'A Thoughtful Display of a Woman And a Astronaut who must Battle a Robot in Berlin', 2006, 1, 3, Decimal('2.99'), 74, Decimal('15.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'angel':1 'astronaut':11 'battl':14 'berlin':18 'display':5 'life':2 'must':13 'robot':16 'thought':4 'woman':8"),
#  (27, 'Anonymous Human', 'A Amazing Reflection of a Database Administrator And a Astronaut who must Outrace a Database Administrator in A Shark Tank', 2006, 1, 7, Decimal('0.99'), 179, Decimal('12.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes', 'Behind the Scenes'], "'administr':9,18 'amaz':4 'anonym':1 'astronaut':12 'databas':8,17 'human':2 'must':14 'outrac':15 'reflect':5 'shark':21 'tank':22"),
#  (70, 'Bikini Borrowers', 'A Astounding Drama of a Astronaut And a Cat who must Discover a Woman in The First Manned Space Station', 2006, 1, 7, Decimal('4.99'), 142, Decimal('26.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes'], "'astound':4 'astronaut':8 'bikini':1 'borrow':2 'cat':11 'discov':14 'drama':5 'first':19 'man':20 'must':13 'space':21 'station':22 'woman':16"),
#  (76, 'Birdcage Casper', 'A Fast-Paced Saga of a Frisbee And a Astronaut who must Overcome a Feminist in Ancient India', 2006, 1, 4, Decimal('0.99'), 103, Decimal('23.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'ancient':20 'astronaut':13 'birdcag':1 'casper':2 'fast':5 'fast-pac':4 'feminist':18 'frisbe':10 'india':21 'must':15 'overcom':16 'pace':6 'saga':7"),
#  (91, 'Bound Cheaper', 'A Thrilling Panorama of a Database Administrator And a Astronaut who must Challenge a Lumberjack in A Baloon', 2006, 1, 5, Decimal('0.99'), 98, Decimal('17.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Behind the Scenes'], "'administr':9 'astronaut':12 'baloon':20 'bound':1 'challeng':15 'cheaper':2 'databas':8 'lumberjack':17 'must':14 'panorama':5 'thrill':4"),
#  (101, 'Brotherhood Blanket', 'A Fateful Character Study of a Butler And a Technical Writer who must Sink a Astronaut in Ancient Japan', 2006, 1, 3, Decimal('0.99'), 73, Decimal('26.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Behind the Scenes'], "'ancient':20 'astronaut':18 'blanket':2 'brotherhood':1 'butler':9 'charact':5 'fate':4 'japan':21 'must':15 'sink':16 'studi':6 'technic':12 'writer':13"),
#  (117, 'Candles Grapes', 'A Fanciful Character Study of a Monkey And a Explorer who must Build a Astronaut in An Abandoned Fun House', 2006, 1, 6, Decimal('4.99'), 135, Decimal('15.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'abandon':20 'astronaut':17 'build':15 'candl':1 'charact':5 'explor':12 'fanci':4 'fun':21 'grape':2 'hous':22 'monkey':9 'must':14 'studi':6"),
#  (122, 'Carrie Bunch', 'A Amazing Epistle of a Student And a Astronaut who must Discover a Frisbee in The Canadian Rockies', 2006, 1, 7, Decimal('0.99'), 114, Decimal('11.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Behind the Scenes'], "'amaz':4 'astronaut':11 'bunch':2 'canadian':19 'carri':1 'discov':14 'epistl':5 'frisbe':16 'must':13 'rocki':20 'student':8"),
#  (130, 'Celebrity Horn', 'A Amazing Documentary of a Secret Agent And a Astronaut who must Vanquish a Hunter in A Shark Tank', 2006, 1, 7, Decimal('0.99'), 110, Decimal('24.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes', 'Behind the Scenes'], "'agent':9 'amaz':4 'astronaut':12 'celebr':1 'documentari':5 'horn':2 'hunter':17 'must':14 'secret':8 'shark':20 'tank':21 'vanquish':15"),
#  (154, 'Clash Freddy', 'A Amazing Yarn of a Composer And a Squirrel who must Escape a Astronaut in Australia', 2006, 1, 6, Decimal('2.99'), 81, Decimal('12.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes'], "'amaz':4 'astronaut':16 'australia':18 'clash':1 'compos':8 'escap':14 'freddi':2 'must':13 'squirrel':11 'yarn':5"),
#  (149, 'Christmas Moonshine', 'A Action-Packed Epistle of a Feminist And a Astronaut who must Conquer a Boat in A Manhattan Penthouse', 2006, 1, 7, Decimal('0.99'), 150, Decimal('21.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Behind the Scenes'], "'action':5 'action-pack':4 'astronaut':13 'boat':18 'christma':1 'conquer':16 'epistl':7 'feminist':10 'manhattan':21 'moonshin':2 'must':15 'pack':6 'penthous':22"),
#  (163, 'Clyde Theory', 'A Beautiful Yarn of a Astronaut And a Frisbee who must Overcome a Explorer in A Jet Boat', 2006, 1, 4, Decimal('0.99'), 139, Decimal('29.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'astronaut':8 'beauti':4 'boat':20 'clyde':1 'explor':16 'frisbe':11 'jet':19 'must':13 'overcom':14 'theori':2 'yarn':5"),
#  (174, 'Confidential Interview', 'A Stunning Reflection of a Cat And a Woman who must Find a Astronaut in Ancient Japan', 2006, 1, 6, Decimal('4.99'), 180, Decimal('13.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries'], "'ancient':18 'astronaut':16 'cat':8 'confidenti':1 'find':14 'interview':2 'japan':19 'must':13 'reflect':5 'stun':4 'woman':11"),
#  (193, 'Crossroads Casualties', 'A Intrepid Documentary of a Sumo Wrestler And a Astronaut who must Battle a Composer in The Outback', 2006, 1, 5, Decimal('2.99'), 153, Decimal('20.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Behind the Scenes'], "'astronaut':12 'battl':15 'casualti':2 'compos':17 'crossroad':1 'documentari':5 'intrepid':4 'must':14 'outback':20 'sumo':8 'wrestler':9"),
#  (195, 'Crowds Telemark', 'A Intrepid Documentary of a Astronaut And a Forensic Psychologist who must Find a Frisbee in An Abandoned Fun House', 2006, 1, 3, Decimal('4.99'), 112, Decimal('16.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Behind the Scenes'], "'abandon':20 'astronaut':8 'crowd':1 'documentari':5 'find':15 'forens':11 'frisbe':17 'fun':21 'hous':22 'intrepid':4 'must':14 'psychologist':12 'telemark':2"),
#  (208, 'Dares Pluto', 'A Fateful Story of a Robot And a Dentist who must Defeat a Astronaut in New Orleans', 2006, 1, 7, Decimal('2.99'), 89, Decimal('16.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Behind the Scenes'], "'astronaut':16 'dare':1 'defeat':14 'dentist':11 'fate':4 'must':13 'new':18 'orlean':19 'pluto':2 'robot':8 'stori':5"),
#  (211, 'Darling Breaking', 'A Brilliant Documentary of a Astronaut And a Squirrel who must Succumb a Student in The Gulf of Mexico', 2006, 1, 7, Decimal('4.99'), 165, Decimal('20.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Behind the Scenes'], "'astronaut':8 'break':2 'brilliant':4 'darl':1 'documentari':5 'gulf':19 'mexico':21 'must':13 'squirrel':11 'student':16 'succumb':14"),
#  (222, 'Desert Poseidon', 'A Brilliant Documentary of a Butler And a Frisbee who must Build a Astronaut in New Orleans', 2006, 1, 4, Decimal('4.99'), 64, Decimal('27.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Behind the Scenes'], "'astronaut':16 'brilliant':4 'build':14 'butler':8 'desert':1 'documentari':5 'frisbe':11 'must':13 'new':18 'orlean':19 'poseidon':2"),
#  (223, 'Desire Alien', 'A Fast-Paced Tale of a Dog And a Forensic Psychologist who must Meet a Astronaut in The First Manned Space Station', 2006, 1, 7, Decimal('2.99'), 76, Decimal('24.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes'], "'alien':2 'astronaut':19 'desir':1 'dog':10 'fast':5 'fast-pac':4 'first':22 'forens':13 'man':23 'meet':17 'must':16 'pace':6 'psychologist':14 'space':24 'station':25 'tale':7"),
#  (239, 'Dogma Family', 'A Brilliant Character Study of a Database Administrator And a Monkey who must Succumb a Astronaut in New Orleans', 2006, 1, 5, Decimal('4.99'), 122, Decimal('16.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries'], "'administr':10 'astronaut':18 'brilliant':4 'charact':5 'databas':9 'dogma':1 'famili':2 'monkey':13 'must':15 'new':20 'orlean':21 'studi':6 'succumb':16"),
#  (275, 'Egypt Tenenbaums', 'A Intrepid Story of a Madman And a Secret Agent who must Outrace a Astronaut in An Abandoned Amusement Park', 2006, 1, 3, Decimal('0.99'), 85, Decimal('11.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'abandon':20 'agent':12 'amus':21 'astronaut':17 'egypt':1 'intrepid':4 'madman':8 'must':14 'outrac':15 'park':22 'secret':11 'stori':5 'tenenbaum':2"),
#  (284, 'Enemy Odds', 'A Fanciful Panorama of a Mad Scientist And a Woman who must Pursue a Astronaut in Ancient India', 2006, 1, 5, Decimal('4.99'), 77, Decimal('23.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'ancient':19 'astronaut':17 'enemi':1 'fanci':4 'india':20 'mad':8 'must':14 'odd':2 'panorama':5 'pursu':15 'scientist':9 'woman':12"),
#  (288, 'Escape Metropolis', 'A Taut Yarn of a Astronaut And a Technical Writer who must Outgun a Boat in New Orleans', 2006, 1, 7, Decimal('2.99'), 167, Decimal('20.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'astronaut':8 'boat':17 'escap':1 'metropoli':2 'must':14 'new':19 'orlean':20 'outgun':15 'taut':4 'technic':11 'writer':12 'yarn':5"),
#  (296, 'Express Lonely', 'A Boring Drama of a Astronaut And a Boat who must Face a Boat in California', 2006, 1, 5, Decimal('2.99'), 178, Decimal('23.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'astronaut':8 'boat':11,16 'bore':4 'california':18 'drama':5 'express':1 'face':14 'lone':2 'must':13"),
#  (319, 'Fish Opus', 'A Touching Display of a Feminist And a Girl who must Confront a Astronaut in Australia', 2006, 1, 4, Decimal('2.99'), 125, Decimal('22.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes', 'Behind the Scenes'], "'astronaut':16 'australia':18 'confront':14 'display':5 'feminist':8 'fish':1 'girl':11 'must':13 'opus':2 'touch':4"),
#  (343, 'Full Flatliners', 'A Beautiful Documentary of a Astronaut And a Moose who must Pursue a Monkey in A Shark Tank', 2006, 1, 6, Decimal('2.99'), 94, Decimal('14.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'astronaut':8 'beauti':4 'documentari':5 'flatlin':2 'full':1 'monkey':16 'moos':11 'must':13 'pursu':14 'shark':19 'tank':20"),
#  (351, 'Gaslight Crusade', 'A Amazing Epistle of a Boy And a Astronaut who must Redeem a Man in The Gulf of Mexico', 2006, 1, 4, Decimal('2.99'), 106, Decimal('10.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'amaz':4 'astronaut':11 'boy':8 'crusad':2 'epistl':5 'gaslight':1 'gulf':19 'man':16 'mexico':21 'must':13 'redeem':14"),
#  (360, 'Glass Dying', 'A Astounding Drama of a Frisbee And a Astronaut who must Fight a Dog in Ancient Japan', 2006, 1, 4, Decimal('0.99'), 103, Decimal('24.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'ancient':18 'astound':4 'astronaut':11 'die':2 'dog':16 'drama':5 'fight':14 'frisbe':8 'glass':1 'japan':19 'must':13"),
#  (385, 'Groundhog Uncut', 'A Brilliant Panorama of a Astronaut And a Technical Writer who must Discover a Butler in A Manhattan Penthouse', 2006, 1, 6, Decimal('4.99'), 139, Decimal('26.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'astronaut':8 'brilliant':4 'butler':17 'discov':15 'groundhog':1 'manhattan':20 'must':14 'panorama':5 'penthous':21 'technic':11 'uncut':2 'writer':12"),
#  (422, 'Hollow Jeopardy', 'A Beautiful Character Study of a Robot And a Astronaut who must Overcome a Boat in A Monastery', 2006, 1, 7, Decimal('4.99'), 136, Decimal('25.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Behind the Scenes'], "'astronaut':12 'beauti':4 'boat':17 'charact':5 'hollow':1 'jeopardi':2 'monasteri':20 'must':14 'overcom':15 'robot':9 'studi':6"),
#  (427, 'Homeward Cider', 'A Taut Reflection of a Astronaut And a Squirrel who must Fight a Squirrel in A Manhattan Penthouse', 2006, 1, 5, Decimal('0.99'), 103, Decimal('19.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'astronaut':8 'cider':2 'fight':14 'homeward':1 'manhattan':19 'must':13 'penthous':20 'reflect':5 'squirrel':11,16 'taut':4"),
#  (458, 'Indian Love', 'A Insightful Saga of a Mad Scientist And a Mad Scientist who must Kill a Astronaut in An Abandoned Fun House', 2006, 1, 4, Decimal('0.99'), 135, Decimal('26.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'abandon':21 'astronaut':18 'fun':22 'hous':23 'indian':1 'insight':4 'kill':16 'love':2 'mad':8,12 'must':15 'saga':5 'scientist':9,13"),
#  (481, 'Jekyll Frogmen', 'A Fanciful Epistle of a Student And a Astronaut who must Kill a Waitress in A Shark Tank', 2006, 1, 4, Decimal('2.99'), 58, Decimal('22.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'astronaut':11 'epistl':5 'fanci':4 'frogmen':2 'jekyl':1 'kill':14 'must':13 'shark':19 'student':8 'tank':20 'waitress':16"),
#  (489, 'Juggler Hardly', 'A Epic Story of a Mad Cow And a Astronaut who must Challenge a Car in California', 2006, 1, 4, Decimal('0.99'), 54, Decimal('14.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries'], "'astronaut':12 'california':19 'car':17 'challeng':15 'cow':9 'epic':4 'hard':2 'juggler':1 'mad':8 'must':14 'stori':5"),
#  (492, 'Jungle Closer', 'A Boring Character Study of a Boy And a Woman who must Battle a Astronaut in Australia', 2006, 1, 6, Decimal('0.99'), 134, Decimal('11.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes'], "'astronaut':17 'australia':19 'battl':15 'bore':4 'boy':9 'charact':5 'closer':2 'jungl':1 'must':14 'studi':6 'woman':12"),
#  (514, 'Lebowski Soldiers', 'A Beautiful Epistle of a Secret Agent And a Pioneer who must Chase a Astronaut in Ancient China', 2006, 1, 6, Decimal('2.99'), 69, Decimal('17.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes'], "'agent':9 'ancient':19 'astronaut':17 'beauti':4 'chase':15 'china':20 'epistl':5 'lebowski':1 'must':14 'pioneer':12 'secret':8 'soldier':2"),
#  (566, 'Maude Mod', 'A Beautiful Documentary of a Forensic Psychologist And a Cat who must Reach a Astronaut in Nigeria', 2006, 1, 6, Decimal('0.99'), 72, Decimal('20.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Behind the Scenes'], "'astronaut':17 'beauti':4 'cat':12 'documentari':5 'forens':8 'maud':1 'mod':2 'must':14 'nigeria':19 'psychologist':9 'reach':15"),
#  (595, 'Moon Bunch', 'A Beautiful Tale of a Astronaut And a Mad Cow who must Challenge a Cat in A Baloon Factory', 2006, 1, 7, Decimal('0.99'), 83, Decimal('20.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes', 'Behind the Scenes'], "'astronaut':8 'baloon':20 'beauti':4 'bunch':2 'cat':17 'challeng':15 'cow':12 'factori':21 'mad':11 'moon':1 'must':14 'tale':5"),
#  (596, 'Moonshine Cabin', 'A Thoughtful Display of a Astronaut And a Feminist who must Chase a Frisbee in A Jet Boat', 2006, 1, 4, Decimal('4.99'), 171, Decimal('25.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Behind the Scenes'], "'astronaut':8 'boat':20 'cabin':2 'chase':14 'display':5 'feminist':11 'frisbe':16 'jet':19 'moonshin':1 'must':13 'thought':4"),
#  (610, 'Music Boondock', 'A Thrilling Tale of a Butler And a Astronaut who must Battle a Explorer in The First Manned Space Station', 2006, 1, 7, Decimal('0.99'), 129, Decimal('17.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Behind the Scenes'], "'astronaut':11 'battl':14 'boondock':2 'butler':8 'explor':16 'first':19 'man':20 'music':1 'must':13 'space':21 'station':22 'tale':5 'thrill':4"),
#  (619, 'Neighbors Charade', 'A Fanciful Reflection of a Crocodile And a Astronaut who must Outrace a Feminist in An Abandoned Amusement Park', 2006, 1, 3, Decimal('0.99'), 161, Decimal('20.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes'], "'abandon':19 'amus':20 'astronaut':11 'charad':2 'crocodil':8 'fanci':4 'feminist':16 'must':13 'neighbor':1 'outrac':14 'park':21 'reflect':5"),
#  (625, 'None Spiking', 'A Boring Reflection of a Secret Agent And a Astronaut who must Face a Composer in A Manhattan Penthouse', 2006, 1, 3, Decimal('0.99'), 83, Decimal('18.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries'], "'agent':9 'astronaut':12 'bore':4 'compos':17 'face':15 'manhattan':20 'must':14 'none':1 'penthous':21 'reflect':5 'secret':8 'spike':2"),
#  (626, 'Noon Papi', 'A Unbelieveable Character Study of a Mad Scientist And a Astronaut who must Find a Pioneer in A Manhattan Penthouse', 2006, 1, 5, Decimal('2.99'), 57, Decimal('12.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Behind the Scenes'], "'astronaut':13 'charact':5 'find':16 'mad':9 'manhattan':21 'must':15 'noon':1 'papi':2 'penthous':22 'pioneer':18 'scientist':10 'studi':6 'unbeliev':4"),
#  (648, 'Outlaw Hanky', 'A Thoughtful Story of a Astronaut And a Composer who must Conquer a Dog in The Sahara Desert', 2006, 1, 7, Decimal('4.99'), 148, Decimal('17.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries'], "'astronaut':8 'compos':11 'conquer':14 'desert':20 'dog':16 'hanki':2 'must':13 'outlaw':1 'sahara':19 'stori':5 'thought':4"),
#  (661, 'Past Suicides', 'A Intrepid Tale of a Madman And a Astronaut who must Challenge a Hunter in A Monastery', 2006, 1, 5, Decimal('4.99'), 157, Decimal('17.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes', 'Behind the Scenes'], "'astronaut':11 'challeng':14 'hunter':16 'intrepid':4 'madman':8 'monasteri':19 'must':13 'past':1 'suicid':2 'tale':5"),
#  (664, 'Patriot Roman', 'A Taut Saga of a Robot And a Database Administrator who must Challenge a Astronaut in California', 2006, 1, 6, Decimal('2.99'), 65, Decimal('12.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'administr':12 'astronaut':17 'california':19 'challeng':15 'databas':11 'must':14 'patriot':1 'robot':8 'roman':2 'saga':5 'taut':4"),
#  (668, 'Peak Forever', 'A Insightful Reflection of a Boat And a Secret Agent who must Vanquish a Astronaut in An Abandoned Mine Shaft', 2006, 1, 7, Decimal('4.99'), 80, Decimal('25.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'abandon':20 'agent':12 'astronaut':17 'boat':8 'forev':2 'insight':4 'mine':21 'must':14 'peak':1 'reflect':5 'secret':11 'shaft':22 'vanquish':15"),
#  (669, 'Pearl Destiny', 'A Lacklusture Yarn of a Astronaut And a Pastry Chef who must Sink a Dog in A U-Boat', 2006, 1, 3, Decimal('2.99'), 74, Decimal('10.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'astronaut':8 'boat':22 'chef':12 'destini':2 'dog':17 'lacklustur':4 'must':14 'pastri':11 'pearl':1 'sink':15 'u':21 'u-boat':20 'yarn':5"),
#  (670, 'Pelican Comforts', 'A Epic Documentary of a Boy And a Monkey who must Pursue a Astronaut in Berlin', 2006, 1, 4, Decimal('4.99'), 48, Decimal('17.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes'], "'astronaut':16 'berlin':18 'boy':8 'comfort':2 'documentari':5 'epic':4 'monkey':11 'must':13 'pelican':1 'pursu':14"),
#  (675, 'Phantom Glory', 'A Beautiful Documentary of a Astronaut And a Crocodile who must Discover a Madman in A Monastery', 2006, 1, 6, Decimal('2.99'), 60, Decimal('17.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Behind the Scenes'], "'astronaut':8 'beauti':4 'crocodil':11 'discov':14 'documentari':5 'glori':2 'madman':16 'monasteri':19 'must':13 'phantom':1"),
#  (676, 'Philadelphia Wife', 'A Taut Yarn of a Hunter And a Astronaut who must Conquer a Database Administrator in The Sahara Desert', 2006, 1, 7, Decimal('4.99'), 137, Decimal('16.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes'], "'administr':17 'astronaut':11 'conquer':14 'databas':16 'desert':21 'hunter':8 'must':13 'philadelphia':1 'sahara':20 'taut':4 'wife':2 'yarn':5"),
#  (687, 'Pocus Pulp', 'A Intrepid Yarn of a Frisbee And a Dog who must Build a Astronaut in A Baloon Factory', 2006, 1, 6, Decimal('0.99'), 138, Decimal('15.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'astronaut':16 'baloon':19 'build':14 'dog':11 'factori':20 'frisbe':8 'intrepid':4 'must':13 'pocus':1 'pulp':2 'yarn':5"),
#  (710, 'Rage Games', 'A Fast-Paced Saga of a Astronaut And a Secret Agent who must Escape a Hunter in An Abandoned Amusement Park', 2006, 1, 4, Decimal('4.99'), 120, Decimal('18.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Behind the Scenes'], "'abandon':22 'agent':14 'amus':23 'astronaut':10 'escap':17 'fast':5 'fast-pac':4 'game':2 'hunter':19 'must':16 'pace':6 'park':24 'rage':1 'saga':7 'secret':13"),
#  (734, 'Road Roxanne', 'A Boring Character Study of a Waitress And a Astronaut who must Fight a Crocodile in Ancient Japan', 2006, 1, 4, Decimal('4.99'), 158, Decimal('12.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Behind the Scenes'], "'ancient':19 'astronaut':12 'bore':4 'charact':5 'crocodil':17 'fight':15 'japan':20 'must':14 'road':1 'roxann':2 'studi':6 'waitress':9"),
#  (737, 'Rock Instinct', 'A Astounding Character Study of a Robot And a Moose who must Overcome a Astronaut in Ancient India', 2006, 1, 4, Decimal('0.99'), 102, Decimal('28.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'ancient':19 'astound':4 'astronaut':17 'charact':5 'india':20 'instinct':2 'moos':12 'must':14 'overcom':15 'robot':9 'rock':1 'studi':6"),
#  (746, 'Rouge Squad', 'A Awe-Inspiring Drama of a Astronaut And a Frisbee who must Conquer a Mad Scientist in Australia', 2006, 1, 3, Decimal('0.99'), 118, Decimal('10.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'astronaut':10 'australia':21 'awe':5 'awe-inspir':4 'conquer':16 'drama':7 'frisbe':13 'inspir':6 'mad':18 'must':15 'roug':1 'scientist':19 'squad':2"),
#  (749, 'Rules Human', 'A Beautiful Epistle of a Astronaut And a Student who must Confront a Monkey in An Abandoned Fun House', 2006, 1, 6, Decimal('4.99'), 153, Decimal('19.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes', 'Behind the Scenes'], "'abandon':19 'astronaut':8 'beauti':4 'confront':14 'epistl':5 'fun':20 'hous':21 'human':2 'monkey':16 'must':13 'rule':1 'student':11"),
#  (760, 'Samurai Lion', 'A Fast-Paced Story of a Pioneer And a Astronaut who must Reach a Boat in A Baloon', 2006, 1, 5, Decimal('2.99'), 110, Decimal('21.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries'], "'astronaut':13 'baloon':21 'boat':18 'fast':5 'fast-pac':4 'lion':2 'must':15 'pace':6 'pioneer':10 'reach':16 'samurai':1 'stori':7"),
#  (766, 'Savannah Town', 'A Awe-Inspiring Tale of a Astronaut And a Database Administrator who must Chase a Secret Agent in The Gulf of Mexico', 2006, 1, 5, Decimal('0.99'), 84, Decimal('25.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'administr':14 'agent':20 'astronaut':10 'awe':5 'awe-inspir':4 'chase':17 'databas':13 'gulf':23 'inspir':6 'mexico':25 'must':16 'savannah':1 'secret':19 'tale':7 'town':2"),
#  (787, 'Shining Roses', 'A Awe-Inspiring Character Study of a Astronaut And a Forensic Psychologist who must Challenge a Madman in Ancient India', 2006, 1, 4, Decimal('0.99'), 125, Decimal('12.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'ancient':22 'astronaut':11 'awe':5 'awe-inspir':4 'challeng':18 'charact':7 'forens':14 'india':23 'inspir':6 'madman':20 'must':17 'psychologist':15 'rose':2 'shine':1 'studi':8"),
#  (833, 'Splendor Patton', 'A Taut Story of a Dog And a Explorer who must Find a Astronaut in Berlin', 2006, 1, 5, Decimal('0.99'), 134, Decimal('20.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'astronaut':16 'berlin':18 'dog':8 'explor':11 'find':14 'must':13 'patton':2 'splendor':1 'stori':5 'taut':4"),
#  (848, 'Stone Fire', 'A Intrepid Drama of a Astronaut And a Crocodile who must Find a Boat in Soviet Georgia', 2006, 1, 3, Decimal('0.99'), 94, Decimal('19.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'astronaut':8 'boat':16 'crocodil':11 'drama':5 'find':14 'fire':2 'georgia':19 'intrepid':4 'must':13 'soviet':18 'stone':1"),
#  (859, 'Sugar Wonka', 'A Touching Story of a Dentist And a Database Administrator who must Conquer a Astronaut in An Abandoned Amusement Park', 2006, 1, 3, Decimal('4.99'), 114, Decimal('20.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Behind the Scenes'], "'abandon':20 'administr':12 'amus':21 'astronaut':17 'conquer':15 'databas':11 'dentist':8 'must':14 'park':22 'stori':5 'sugar':1 'touch':4 'wonka':2"),
#  (866, 'Sunset Racer', 'A Awe-Inspiring Reflection of a Astronaut And a A Shark who must Defeat a Forensic Psychologist in California', 2006, 1, 6, Decimal('0.99'), 48, Decimal('28.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Behind the Scenes'], "'astronaut':10 'awe':5 'awe-inspir':4 'california':22 'defeat':17 'forens':19 'inspir':6 'must':16 'psychologist':20 'racer':2 'reflect':7 'shark':14 'sunset':1"),
#  (889, 'Ties Hunger', 'A Insightful Saga of a Astronaut And a Explorer who must Pursue a Mad Scientist in A U-Boat', 2006, 1, 3, Decimal('4.99'), 111, Decimal('28.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes'], "'astronaut':8 'boat':22 'explor':11 'hunger':2 'insight':4 'mad':16 'must':13 'pursu':14 'saga':5 'scientist':17 'tie':1 'u':21 'u-boat':20"),
#  (894, 'Tomatoes Hellfighters', 'A Thoughtful Epistle of a Madman And a Astronaut who must Overcome a Monkey in A Shark Tank', 2006, 1, 6, Decimal('0.99'), 68, Decimal('23.99'), 'PG', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Behind the Scenes'], "'astronaut':11 'epistl':5 'hellfight':2 'madman':8 'monkey':16 'must':13 'overcom':14 'shark':19 'tank':20 'thought':4 'tomato':1"),
#  (898, 'Tourist Pelican', 'A Boring Story of a Butler And a Astronaut who must Outrace a Pioneer in Australia', 2006, 1, 4, Decimal('4.99'), 152, Decimal('18.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Deleted Scenes'], "'astronaut':11 'australia':18 'bore':4 'butler':8 'must':13 'outrac':14 'pelican':2 'pioneer':16 'stori':5 'tourist':1"),
#  (926, 'Untouchables Sunrise', 'A Amazing Documentary of a Woman And a Astronaut who must Outrace a Teacher in An Abandoned Fun House', 2006, 1, 5, Decimal('2.99'), 120, Decimal('11.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Deleted Scenes'], "'abandon':19 'amaz':4 'astronaut':11 'documentari':5 'fun':20 'hous':21 'must':13 'outrac':14 'sunris':2 'teacher':16 'untouch':1 'woman':8"),
#  (932, 'Valley Packer', 'A Astounding Documentary of a Astronaut And a Boy who must Outrace a Sumo Wrestler in Berlin', 2006, 1, 3, Decimal('0.99'), 73, Decimal('21.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes'], "'astound':4 'astronaut':8 'berlin':19 'boy':11 'documentari':5 'must':13 'outrac':14 'packer':2 'sumo':16 'valley':1 'wrestler':17"),
#  (937, 'Varsity Trip', 'A Action-Packed Character Study of a Astronaut And a Explorer who must Reach a Monkey in A MySQL Convention', 2006, 1, 7, Decimal('2.99'), 85, Decimal('14.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes'], "'action':5 'action-pack':4 'astronaut':11 'charact':7 'convent':23 'explor':14 'monkey':19 'must':16 'mysql':22 'pack':6 'reach':17 'studi':8 'trip':2 'varsiti':1"),
#  (941, 'Videotape Arsenic', 'A Lacklusture Display of a Girl And a Astronaut who must Succumb a Student in Australia', 2006, 1, 4, Decimal('4.99'), 145, Decimal('10.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Commentaries', 'Deleted Scenes', 'Behind the Scenes'], "'arsenic':2 'astronaut':11 'australia':18 'display':5 'girl':8 'lacklustur':4 'must':13 'student':16 'succumb':14 'videotap':1"),
#  (953, 'Wait Cider', 'A Intrepid Epistle of a Woman And a Forensic Psychologist who must Succumb a Astronaut in A Manhattan Penthouse', 2006, 1, 3, Decimal('0.99'), 112, Decimal('9.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'astronaut':17 'cider':2 'epistl':5 'forens':11 'intrepid':4 'manhattan':20 'must':14 'penthous':21 'psychologist':12 'succumb':15 'wait':1 'woman':8"),
#  (958, 'Wardrobe Phantom', 'A Action-Packed Display of a Mad Cow And a Astronaut who must Kill a Car in Ancient India', 2006, 1, 6, Decimal('2.99'), 178, Decimal('19.99'), 'G', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries'], "'action':5 'action-pack':4 'ancient':21 'astronaut':14 'car':19 'cow':11 'display':7 'india':22 'kill':17 'mad':10 'must':16 'pack':6 'phantom':2 'wardrob':1"),
#  (975, 'Willow Tracy', 'A Brilliant Panorama of a Boat And a Astronaut who must Challenge a Teacher in A Manhattan Penthouse', 2006, 1, 6, Decimal('2.99'), 137, Decimal('22.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Behind the Scenes'], "'astronaut':11 'boat':8 'brilliant':4 'challeng':14 'manhattan':19 'must':13 'panorama':5 'penthous':20 'teacher':16 'traci':2 'willow':1"),
#  (990, 'World Leathernecks', 'A Unbelieveable Tale of a Pioneer And a Astronaut who must Overcome a Robot in An Abandoned Amusement Park', 2006, 1, 3, Decimal('0.99'), 171, Decimal('13.99'), 'PG-13', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Behind the Scenes'], "'abandon':19 'amus':20 'astronaut':11 'leatherneck':2 'must':13 'overcom':14 'park':21 'pioneer':8 'robot':16 'tale':5 'unbeliev':4 'world':1"),
#  (995, 'Yentl Idaho', 'A Amazing Display of a Robot And a Astronaut who must Fight a Womanizer in Berlin', 2006, 1, 5, Decimal('4.99'), 86, Decimal('11.99'), 'R', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers', 'Commentaries', 'Deleted Scenes'], "'amaz':4 'astronaut':11 'berlin':18 'display':5 'fight':14 'idaho':2 'must':13 'robot':8 'woman':16 'yentl':1")]

# %% [markdown]
# Number of films about 'astronaut'

# %%
# %%sql
#
# SELECT count(*) AS number_of_films_about_astronout
#     FROM film
#     WHERE fulltext @@ to_tsquery('astronaut');
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 1 rows affected.
# [(78,)]

# %% [markdown]
# ## QUESTION 2
# Films which have rating 'R' and replacement cost between \\$5 and \\$15

# %%
# %%sql
#
# SELECT title, rating,replacement_cost
#     FROM film
#     where (rating = 'R') AND (replacement_cost between 5 AND 15);
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 52 rows affected.
# [('Alone Trip', 'R', Decimal('14.99')),
#  ('Anaconda Confessions', 'R', Decimal('9.99')),
#  ('Apocalypse Flamingos', 'R', Decimal('11.99')),
#  ('Boogie Amelie', 'R', Decimal('11.99')),
#  ('Boulevard Mob', 'R', Decimal('11.99')),
#  ('Candidate Perdition', 'R', Decimal('10.99')),
#  ('Chocolate Duck', 'R', Decimal('13.99')),
#  ('Closer Bang', 'R', Decimal('12.99')),
#  ('Clueless Bucket', 'R', Decimal('13.99')),
#  ('Commandments Express', 'R', Decimal('13.99')),
#  ('Conversation Downhill', 'R', Decimal('14.99')),
#  ('Deliverance Mulholland', 'R', Decimal('9.99')),
#  ('Devil Desire', 'R', Decimal('12.99')),
#  ('Doom Dancing', 'R', Decimal('13.99')),
#  ('Durham Panky', 'R', Decimal('14.99')),
#  ('Fight Jawbreaker', 'R', Decimal('13.99')),
#  ('Finding Anaconda', 'R', Decimal('10.99')),
#  ('Frida Slipper', 'R', Decimal('11.99')),
#  ('Galaxy Sweethearts', 'R', Decimal('13.99')),
#  ('Giant Troopers', 'R', Decimal('10.99')),
#  ('Go Purple', 'R', Decimal('12.99')),
#  ('Greedy Roots', 'R', Decimal('14.99')),
#  ('Highball Potter', 'R', Decimal('10.99')),
#  ('Holocaust Highball', 'R', Decimal('12.99')),
#  ('House Dynamite', 'R', Decimal('13.99')),
#  ('Jeopardy Encino', 'R', Decimal('12.99')),
#  ('Jet Neighbors', 'R', Decimal('14.99')),
#  ('Killer Innocent', 'R', Decimal('11.99')),
#  ('Kissing Dolls', 'R', Decimal('9.99')),
#  ('Lock Rear', 'R', Decimal('10.99')),
#  ('Madison Trap', 'R', Decimal('11.99')),
#  ('Oz Liaisons', 'R', Decimal('14.99')),
#  ('Pajama Jawbreaker', 'R', Decimal('14.99')),
#  ('Pluto Oleander', 'R', Decimal('9.99')),
#  ('Prix Undefeated', 'R', Decimal('13.99')),
#  ('Purple Movie', 'R', Decimal('9.99')),
#  ('Road Roxanne', 'R', Decimal('12.99')),
#  ('Roxanne Rebel', 'R', Decimal('9.99')),
#  ('Shepherd Midsummer', 'R', Decimal('14.99')),
#  ('Shrunk Divine', 'R', Decimal('14.99')),
#  ('Sling Luke', 'R', Decimal('10.99')),
#  ('Soup Wisdom', 'R', Decimal('12.99')),
#  ('Tights Dawn', 'R', Decimal('14.99')),
#  ('Streetcar Intentions', 'R', Decimal('11.99')),
#  ('Suit Walls', 'R', Decimal('12.99')),
#  ('Sun Confessions', 'R', Decimal('9.99')),
#  ('Terminator Club', 'R', Decimal('11.99')),
#  ('Unfaithful Kill', 'R', Decimal('12.99')),
#  ('Velvet Terminator', 'R', Decimal('14.99')),
#  ('Wind Phantom', 'R', Decimal('12.99')),
#  ('Wisdom Worker', 'R', Decimal('12.99')),
#  ('Yentl Idaho', 'R', Decimal('11.99'))]

# %% [markdown]
# Number of films with rating 'R' and replacement cost between $5 and $15

# %%
# %%sql
#
# SELECT count(film_id) AS film_rating_r_rc_5_and_15
#     FROM film where (rating = 'R') AND (replacement_cost between 5 and 15);
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 1 rows affected.
# [(52,)]

# %% [markdown]
# ## QUESTION 3
# The number of payment and the total amount for each staff

# %%
# %%sql
#
# SELECT staff_id, count(payment_id) AS payment, sum(amount) AS amount
#     FROM payment
#     GROUP BY staff_id
#     ORDER BY amount desc;
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 2 rows affected.
# [(2, 7304, Decimal('31059.92')), (1, 7292, Decimal('30252.12'))]

# %% [markdown]
# Name of staff, number of payment, and total amount for each staff

# %%
# %%sql
#
# SELECT concat(s.first_name, ' ', s.last_name) AS fullname, s.staff_id, count(p.payment_id) AS payment, sum(p.amount) AS amount
#     FROM payment p
#     INNER JOIN staff s
#     ON p.staff_id = s.staff_id
#     GROUP BY s.staff_id
#     ORDER BY amount desc;
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 2 rows affected.
# [('Jon Stephens', 2, 7304, Decimal('31059.92')),
#  ('Mike Hillyer', 1, 7292, Decimal('30252.12'))]

# %% [markdown]
# ## QUESTION 4
# The average of replacement cost of movies by rating

# %%
# %%sql
#
# SELECT rating, avg(replacement_cost) AS avg_replacement_cost
#     FROM film
#     GROUP BY rating
#     ORDER BY avg_replacement_cost desc;
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 5 rows affected.
# [('PG-13', Decimal('20.4025560538116592')),
#  ('R', Decimal('20.2310256410256410')),
#  ('NC-17', Decimal('20.1376190476190476')),
#  ('G', Decimal('20.1248314606741573')),
#  ('PG', Decimal('18.9590721649484536'))]

# %% [markdown]
# ## QUESTION 5
# 5 customers who have spent the most amount of money

# %%
# %%sql
#
# SELECT concat(c.first_name,' ', c.last_name) AS fullname, c.email, sum(p.amount) AS sum_amount
#     FROM customer c
#     INNER JOIN payment p
#     ON c.customer_id = p.customer_id
#     GROUP BY c.customer_id
#     ORDER BY sum_amount desc
#     LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 5 rows affected.
# [('Eleanor Hunt', 'eleanor.hunt@sakilacustomer.org', Decimal('211.55')),
#  ('Karl Seal', 'karl.seal@sakilacustomer.org', Decimal('208.58')),
#  ('Marion Snyder', 'marion.snyder@sakilacustomer.org', Decimal('194.61')),
#  ('Rhonda Kennedy', 'rhonda.kennedy@sakilacustomer.org', Decimal('191.62')),
#  ('Clara Shaw', 'clara.shaw@sakilacustomer.org', Decimal('189.60'))]

# %% [markdown]
# ## QUESTION 6
# Number of copies of each movie in each store

# %%
# %%sql
#
# SELECT i.store_id, f.title, count(i.film_id) AS count_film
#     FROM inventory i
#     INNER JOIN film f
#     ON i.film_id = f.film_id
#     GROUP BY i.store_id, f.title
#     ORDER BY i.store_id, f.title;
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 1521 rows affected.
# [(1, 'Academy Dinosaur', 4),
#  (1, 'Affair Prejudice', 4),
#  (1, 'Agent Truman', 3),
#  (1, 'Airplane Sierra', 2),
#  (1, 'Alabama Devil', 3),
#  (1, 'Aladdin Calendar', 4),
#  (1, 'Alamo Videotape', 4),
#  (1, 'Alaska Phantom', 3),
#  (1, 'Alien Center', 2),
#  (1, 'Alley Evolution', 2),
#  (1, 'Alone Trip', 3),
#  (1, 'Alter Victory', 3),
#  (1, 'Amadeus Holy', 4),
#  (1, 'Amelie Hellfighters', 3),
#  (1, 'American Circus', 2),
#  (1, 'Amistad Midsummer', 4),
#  (1, 'Anaconda Confessions', 3),
#  (1, 'Analyze Hoosiers', 4),
#  (1, 'Angels Life', 4),
#  (1, 'Annie Identity', 2),
#  (1, 'Anonymous Human', 4),
#  (1, 'Anthem Luke', 3),
#  (1, 'Antitrust Tomatoes', 2),
#  (1, 'Anything Savannah', 2),
#  (1, 'Apache Divine', 4),
#  (1, 'Arachnophobia Rollercoaster', 4),
#  (1, 'Arizona Bang', 4),
#  (1, 'Armageddon Lost', 3),
#  (1, 'Atlantis Cause', 3),
#  (1, 'Attacks Hate', 2),
#  (1, 'Attraction Newton', 4),
#  (1, 'Backlash Undefeated', 2),
#  (1, 'Badman Dawn', 3),
#  (1, 'Baked Cleopatra', 3),
#  (1, 'Balloon Homeward', 2),
#  (1, 'Bang Kwai', 2),
#  (1, 'Banger Pinocchio', 3),
#  (1, 'Barbarella Streetcar', 4),
#  (1, 'Barefoot Manchurian', 3),
#  (1, 'Basic Easy', 4),
#  (1, 'Bear Graceland', 3),
#  (1, 'Beast Hunchback', 3),
#  (1, 'Beauty Grease', 4),
#  (1, 'Bedazzled Married', 2),
#  (1, 'Beneath Rush', 3),
#  (1, 'Berets Agent', 2),
#  (1, 'Betrayed Rear', 2),
#  (1, 'Beverly Outlaw', 4),
#  (1, 'Bikini Borrowers', 2),
#  (1, 'Bill Others', 4),
#  (1, 'Bingo Talented', 4),
#  (1, 'Birch Antitrust', 3),
#  (1, 'Birdcage Casper', 3),
#  (1, 'Birds Perdition', 4),
#  (1, 'Blackout Private', 3),
#  (1, 'Blade Polish', 3),
#  (1, 'Blanket Beverly', 4),
#  (1, 'Blindness Gun', 4),
#  (1, 'Blood Argonauts', 2),
#  (1, 'Blues Instinct', 3),
#  (1, 'Boiled Dares', 4),
#  (1, 'Boogie Amelie', 4),
#  (1, 'Borrowers Bedazzled', 3),
#  (1, 'Boulevard Mob', 3),
#  (1, 'Bound Cheaper', 4),
#  (1, 'Bowfinger Gables', 2),
#  (1, 'Braveheart Human', 2),
#  (1, 'Breakfast Goldfinger', 2),
#  (1, 'Breaking Home', 3),
#  (1, 'Bride Intrigue', 4),
#  (1, 'Bright Encounters', 3),
#  (1, 'Bringing Hysterical', 3),
#  (1, 'Brooklyn Desert', 4),
#  (1, 'Brotherhood Blanket', 4),
#  (1, 'Bucket Brotherhood', 4),
#  (1, 'Bull Shawshank', 2),
#  (1, 'Bulworth Commandments', 2),
#  (1, 'Butterfly Chocolat', 4),
#  (1, 'Cabin Flash', 4),
#  (1, 'Calendar Gunfight', 4),
#  (1, 'Camelot Vacation', 4),
#  (1, 'Campus Remember', 3),
#  (1, 'Candidate Perdition', 2),
#  (1, 'Candles Grapes', 4),
#  (1, 'Canyon Stock', 4),
#  (1, 'Caper Motions', 3),
#  (1, 'Caribbean Liberty', 3),
#  (1, 'Carol Texas', 3),
#  (1, 'Carrie Bunch', 4),
#  (1, 'Casablanca Super', 2),
#  (1, 'Cat Coneheads', 4),
#  (1, 'Cause Date', 3),
#  (1, 'Celebrity Horn', 2),
#  (1, 'Center Dinosaur', 4),
#  (1, 'Chainsaw Uptown', 4),
#  (1, 'Chamber Italian', 2),
#  (1, 'Chance Resurrection', 3),
#  (1, 'Chaplin License', 3),
#  (1, 'Chariots Conspiracy', 2),
#  (1, 'Chasing Fight', 4),
#  (1, 'Cheaper Clyde', 2),
#  (1, 'Chicago North', 3),
#  (1, 'Chicken Hellfighters', 3),
#  (1, 'Chill Luck', 4),
#  (1, 'Chitty Lock', 3),
#  (1, 'Chocolat Harry', 3),
#  (1, 'Christmas Moonshine', 3),
#  (1, 'Cider Desire', 2),
#  (1, 'Cincinatti Whisperer', 2),
#  (1, 'Circus Youth', 4),
#  (1, 'Citizen Shrek', 4),
#  (1, 'Clash Freddy', 3),
#  (1, 'Cleopatra Devil', 2),
#  (1, 'Clones Pinocchio', 2),
#  (1, 'Closer Bang', 4),
#  (1, 'Club Graffiti', 2),
#  (1, 'Clue Grail', 2),
#  (1, 'Clueless Bucket', 3),
#  (1, 'Coast Rainbow', 2),
#  (1, 'Coldblooded Darling', 3),
#  (1, 'Color Philadelphia', 4),
#  (1, 'Coma Head', 4),
#  (1, 'Comancheros Enemy', 2),
#  (1, 'Comforts Rush', 2),
#  (1, 'Command Darling', 2),
#  (1, 'Coneheads Smoochy', 4),
#  (1, 'Confessions Maguire', 3),
#  (1, 'Confidential Interview', 4),
#  (1, 'Confused Candles', 2),
#  (1, 'Congeniality Quest', 2),
#  (1, 'Connection Microcosmos', 2),
#  (1, 'Conquerer Nuts', 4),
#  (1, 'Contact Anonymous', 3),
#  (1, 'Control Anthem', 2),
#  (1, 'Conversation Downhill', 3),
#  (1, 'Core Suit', 2),
#  (1, 'Cowboy Doom', 2),
#  (1, 'Craft Outfield', 2),
#  (1, 'Crazy Home', 3),
#  (1, 'Creatures Shakespeare', 2),
#  (1, 'Crooked Frogmen', 3),
#  (1, 'Crossroads Casualties', 4),
#  (1, 'Crow Grease', 2),
#  (1, 'Cruelty Unforgiven', 2),
#  (1, 'Crusade Honey', 2),
#  (1, 'Cupboard Sinners', 4),
#  (1, 'Curtain Videotape', 4),
#  (1, 'Cyclone Family', 4),
#  (1, 'Daddy Pittsburgh', 3),
#  (1, 'Dalmations Sweden', 4),
#  (1, 'Dances None', 4),
#  (1, 'Dancing Fever', 4),
#  (1, 'Dangerous Uptown', 4),
#  (1, 'Dares Pluto', 3),
#  (1, 'Darkness War', 4),
#  (1, 'Darling Breaking', 2),
#  (1, 'Darn Forrester', 3),
#  (1, 'Date Speed', 4),
#  (1, 'Dawn Pond', 3),
#  (1, 'Day Unfaithful', 2),
#  (1, 'Deceiver Betrayed', 4),
#  (1, 'Deep Crusade', 4),
#  (1, 'Deer Virginian', 4),
#  (1, 'Desert Poseidon', 2),
#  (1, 'Desperate Trainspotting', 2),
#  (1, 'Destination Jerk', 3),
#  (1, 'Destiny Saturday', 2),
#  (1, 'Details Packer', 3),
#  (1, 'Detective Vision', 3),
#  (1, 'Devil Desire', 2),
#  (1, 'Diary Panic', 2),
#  (1, 'Dinosaur Secretary', 4),
#  (1, 'Dirty Ace', 3),
#  (1, 'Disciple Mother', 4),
#  (1, 'Disturbing Scarface', 4),
#  (1, 'Divide Monster', 2),
#  (1, 'Divorce Shining', 2),
#  (1, 'Doctor Grail', 2),
#  (1, 'Dogma Family', 4),
#  (1, 'Donnie Alley', 4),
#  (1, 'Doom Dancing', 2),
#  (1, 'Doors President', 2),
#  (1, 'Dorado Notting', 4),
#  (1, 'Double Wrath', 3),
#  (1, 'Downhill Enough', 3),
#  (1, 'Dracula Crystal', 2),
#  (1, 'Dragonfly Strangers', 2),
#  (1, 'Dream Pickup', 3),
#  (1, 'Drifter Commandments', 4),
#  (1, 'Driver Annie', 2),
#  (1, 'Driving Polish', 4),
#  (1, 'Duck Racer', 2),
#  (1, 'Duffel Apocalypse', 2),
#  (1, 'Durham Panky', 4),
#  (1, 'Dying Maker', 4),
#  (1, 'Dynamite Tarzan', 4),
#  (1, 'Eagles Panky', 4),
#  (1, 'Earring Instinct', 2),
#  (1, 'Earth Vision', 3),
#  (1, 'Easy Gladiator', 3),
#  (1, 'Edge Kissing', 4),
#  (1, 'Effect Gladiator', 4),
#  (1, 'Egg Igby', 3),
#  (1, 'Egypt Tenenbaums', 3),
#  (1, 'Element Freddy', 4),
#  (1, 'Elephant Trojan', 3),
#  (1, 'Elf Murder', 2),
#  (1, 'Elizabeth Shane', 2),
#  (1, 'Empire Malkovich', 4),
#  (1, 'Encino Elf', 2),
#  (1, 'Encounters Curtain', 3),
#  (1, 'Ending Crowds', 3),
#  (1, 'Enemy Odds', 3),
#  (1, 'English Bulworth', 3),
#  (1, 'Enough Raging', 2),
#  (1, 'Entrapment Satisfaction', 2),
#  (1, 'Escape Metropolis', 2),
#  (1, 'Eve Resurrection', 2),
#  (1, 'Everyone Craft', 3),
#  (1, 'Evolution Alter', 4),
#  (1, 'Excitement Eve', 3),
#  (1, 'Exorcist Sting', 2),
#  (1, 'Expecations Natural', 2),
#  (1, 'Expendable Stallion', 4),
#  (1, 'Express Lonely', 4),
#  (1, 'Eyes Driving', 2),
#  (1, 'Factory Dragon', 4),
#  (1, 'Falcon Volume', 2),
#  (1, 'Family Sweet', 4),
#  (1, 'Fantasia Park', 2),
#  (1, 'Fantasy Troopers', 4),
#  (1, 'Fargo Gandhi', 4),
#  (1, 'Fatal Haunted', 4),
#  (1, 'Feathers Metal', 3),
#  (1, 'Fellowship Autumn', 3),
#  (1, 'Ferris Mother', 2),
#  (1, 'Feud Frogmen', 2),
#  (1, 'Fever Empire', 2),
#  (1, 'Fiction Christmas', 3),
#  (1, 'Fidelity Devil', 4),
#  (1, 'Fight Jawbreaker', 2),
#  (1, 'Fireball Philadelphia', 4),
#  (1, 'Fish Opus', 3),
#  (1, 'Flamingos Connecticut', 3),
#  (1, 'Flash Wars', 4),
#  (1, 'Flatliners Killer', 4),
#  (1, 'Flintstones Happiness', 3),
#  (1, 'Flying Hook', 2),
#  (1, 'Fool Mockingbird', 4),
#  (1, 'Forrest Sons', 3),
#  (1, 'Forrester Comancheros', 4),
#  (1, 'Forward Temple', 4),
#  (1, 'Freaky Pocus', 2),
#  (1, 'Freddy Storm', 2),
#  (1, 'Freedom Cleopatra', 2),
#  (1, 'French Holiday', 3),
#  (1, 'Frida Slipper', 2),
#  (1, 'Frontier Cabin', 2),
#  (1, 'Frost Head', 4),
#  (1, 'Fugitive Maguire', 4),
#  (1, 'Full Flatliners', 2),
#  (1, 'Fury Murder', 3),
#  (1, 'Gables Metropolis', 3),
#  (1, 'Galaxy Sweethearts', 2),
#  (1, 'Games Bowfinger', 4),
#  (1, 'Gangs Pride', 4),
#  (1, 'Garden Island', 4),
#  (1, 'Gaslight Crusade', 3),
#  (1, 'Gentlemen Stage', 2),
#  (1, 'Ghost Groundhog', 3),
#  (1, 'Giant Troopers', 4),
#  (1, 'Gilmore Boiled', 4),
#  (1, 'Glass Dying', 4),
#  (1, 'Gleaming Jawbreaker', 4),
#  (1, 'Glory Tracy', 2),
#  (1, 'Go Purple', 3),
#  (1, 'Godfather Diary', 3),
#  (1, 'Gold River', 2),
#  (1, 'Goldfinger Sensibility', 4),
#  (1, 'Goldmine Tycoon', 4),
#  (1, 'Gone Trouble', 2),
#  (1, 'Goodfellas Salute', 4),
#  (1, 'Gorgeous Bingo', 3),
#  (1, 'Gosford Donnie', 3),
#  (1, 'Graceland Dynamite', 2),
#  (1, 'Graduate Lord', 3),
#  (1, 'Graffiti Love', 3),
#  (1, 'Grail Frankenstein', 2),
#  (1, 'Grapes Fury', 4),
#  (1, 'Grease Youth', 3),
#  (1, 'Greatest North', 4),
#  (1, 'Greek Everyone', 2),
#  (1, 'Grinch Massage', 2),
#  (1, 'Grit Clockwork', 4),
#  (1, 'Groove Fiction', 3),
#  (1, 'Groundhog Uncut', 2),
#  (1, 'Gun Bonnie', 3),
#  (1, 'Gunfight Moon', 3),
#  (1, 'Gunfighter Mussolini', 2),
#  (1, 'Guys Falcon', 3),
#  (1, 'Half Outfield', 4),
#  (1, 'Hall Cassidy', 4),
#  (1, 'Halloween Nuts', 2),
#  (1, 'Hamlet Wisdom', 4),
#  (1, 'Handicap Boondock', 3),
#  (1, 'Hanky October', 3),
#  (1, 'Hardly Robbers', 2),
#  (1, 'Harold French', 2),
#  (1, 'Harper Dying', 3),
#  (1, 'Harry Idaho', 4),
#  (1, 'Haunting Pianist', 2),
#  (1, 'Hawk Chill', 2),
#  (1, 'Head Stranger', 4),
#  (1, 'Heartbreakers Bright', 4),
#  (1, 'Heaven Freedom', 3),
#  (1, 'Heavenly Gun', 2),
#  (1, 'Heavyweights Beast', 4),
#  (1, 'Hedwig Alter', 3),
#  (1, 'Hellfighters Sierra', 3),
#  (1, 'High Encino', 3),
#  (1, 'Highball Potter', 2),
#  (1, 'Hills Neighbors', 4),
#  (1, 'Hobbit Alien', 4),
#  (1, 'Holes Brannigan', 2),
#  (1, 'Hollywood Anonymous', 2),
#  (1, 'Holocaust Highball', 3),
#  (1, 'Homeward Cider', 4),
#  (1, 'Homicide Peach', 4),
#  (1, 'Honey Ties', 2),
#  (1, 'Hope Tootsie', 3),
#  (1, 'Horn Working', 4),
#  (1, 'Horror Reign', 4),
#  (1, 'Hotel Happiness', 2),
#  (1, 'Hours Rage', 3),
#  (1, 'House Dynamite', 2),
#  (1, 'Human Graffiti', 2),
#  (1, 'Hunchback Impossible', 4),
#  (1, 'Hunger Roof', 2),
#  (1, 'Hunter Alter', 2),
#  (1, 'Hunting Musketeers', 3),
#  (1, 'Hurricane Affair', 3),
#  (1, 'Hustler Party', 4),
#  (1, 'Hyde Doctor', 3),
#  (1, 'Hysterical Grail', 2),
#  (1, 'Ice Crossing', 4),
#  (1, 'Idaho Love', 2),
#  (1, 'Idols Snatchers', 3),
#  (1, 'Igby Maker', 2),
#  (1, 'Image Princess', 3),
#  (1, 'Impact Aladdin', 2),
#  (1, 'Impossible Prejudice', 4),
#  (1, 'Inch Jet', 2),
#  (1, 'Independence Hotel', 2),
#  (1, 'Indian Love', 2),
#  (1, 'Innocent Usual', 4),
#  (1, 'Insects Stone', 2),
#  (1, 'Insider Arizona', 2),
#  (1, 'Instinct Airport', 3),
#  (1, 'Intentions Empire', 4),
#  (1, 'Interview Liaisons', 2),
#  (1, 'Intolerable Intentions', 2),
#  (1, 'Intrigue Worst', 4),
#  (1, 'Invasion Cyclone', 4),
#  (1, 'Ishtar Rocketeer', 2),
#  (1, 'Island Exorcist', 3),
#  (1, 'Jacket Frisco', 2),
#  (1, 'Jason Trap', 3),
#  (1, 'Jaws Harry', 2),
#  (1, 'Jedi Beneath', 2),
#  (1, 'Jeepers Wedding', 2),
#  (1, 'Jekyll Frogmen', 3),
#  (1, 'Jeopardy Encino', 3),
#  (1, 'Jericho Mulan', 3),
#  (1, 'Jerk Paycheck', 4),
#  (1, 'Jet Neighbors', 4),
#  (1, 'Joon Northwest', 2),
#  (1, 'Juggler Hardly', 4),
#  (1, 'Jumanji Blade', 2),
#  (1, 'Jumping Wrath', 2),
#  (1, 'Jungle Closer', 2),
#  (1, 'Karate Moon', 4),
#  (1, 'Kick Savannah', 2),
#  (1, 'Killer Innocent', 2),
#  (1, 'King Evolution', 2),
#  (1, 'Kiss Glory', 4),
#  (1, 'Kissing Dolls', 3),
#  (1, 'Knock Warlock', 4),
#  (1, 'Kramer Chocolate', 3),
#  (1, 'Kwai Homeward', 4),
#  (1, 'Lady Stage', 4),
#  (1, 'Lawless Vision', 4),
#  (1, 'Lawrence Love', 2),
#  (1, 'League Hellfighters', 2),
#  (1, 'Lebowski Soldiers', 2),
#  (1, 'Liaisons Sweet', 2),
#  (1, 'License Weekend', 2),
#  (1, 'Lies Treatment', 4),
#  (1, 'Lights Deer', 2),
#  (1, 'Lion Uncut', 2),
#  (1, 'Loathing Legally', 4),
#  (1, 'Lola Agent', 2),
#  (1, 'Lolita World', 3),
#  (1, 'Lonely Elephant', 4),
#  (1, 'Lord Arizona', 3),
#  (1, 'Lose Inch', 4),
#  (1, 'Lost Bird', 3),
#  (1, 'Louisiana Harry', 2),
#  (1, 'Love Suicides', 4),
#  (1, 'Lovely Jingle', 3),
#  (1, 'Luck Opus', 2),
#  (1, 'Lucky Flying', 3),
#  (1, 'Lust Lock', 4),
#  (1, 'Madigan Dorado', 2),
#  (1, 'Madison Trap', 2),
#  (1, 'Madness Attacks', 4),
#  (1, 'Magnificent Chitty', 2),
#  (1, 'Magnolia Forrester', 2),
#  (1, 'Maguire Apache', 3),
#  (1, 'Maiden Home', 3),
#  (1, 'Malkovich Pet', 4),
#  (1, 'Mallrats United', 3),
#  (1, 'Maltese Hope', 3),
#  (1, 'Manchurian Curtain', 2),
#  (1, 'Married Go', 4),
#  (1, 'Mars Roman', 3),
#  (1, 'Mask Peach', 4),
#  (1, 'Masked Bubble', 4),
#  (1, 'Massacre Usual', 4),
#  (1, 'Matrix Snowman', 2),
#  (1, 'Maude Mod', 2),
#  (1, 'Meet Chocolate', 2),
#  (1, 'Memento Zoolander', 2),
#  (1, 'Menagerie Rushmore', 2),
#  (1, 'Mermaid Insects', 2),
#  (1, 'Metal Armageddon', 2),
#  (1, 'Metropolis Coma', 4),
#  (1, 'Microcosmos Paradise', 4),
#  (1, 'Midnight Westward', 2),
#  (1, 'Midsummer Groundhog', 2),
#  (1, 'Mile Mulan', 3),
#  (1, 'Million Ace', 2),
#  (1, 'Minds Truman', 4),
#  (1, 'Mine Titans', 4),
#  (1, 'Minority Kiss', 3),
#  (1, 'Mission Zoolander', 3),
#  (1, 'Mixed Doors', 2),
#  (1, 'Mockingbird Hollywood', 4),
#  (1, 'Mod Secretary', 3),
#  (1, 'Money Harold', 3),
#  (1, 'Monster Spartacus', 2),
#  (1, 'Montezuma Command', 3),
#  (1, 'Moon Bunch', 4),
#  (1, 'Moonshine Cabin', 2),
#  (1, 'Mosquito Armageddon', 4),
#  (1, 'Mother Oleander', 3),
#  (1, 'Motions Details', 2),
#  (1, 'Moulin Wake', 3),
#  (1, 'Mourning Purple', 2),
#  (1, 'Movie Shakespeare', 4),
#  (1, 'Mummy Creatures', 2),
#  (1, 'Murder Antitrust', 2),
#  (1, 'Muscle Bright', 4),
#  (1, 'Music Boondock', 2),
#  (1, 'Musketeers Wait', 4),
#  (1, 'Mystic Truman', 2),
#  (1, 'Name Detective', 3),
#  (1, 'National Story', 2),
#  (1, 'Natural Stock', 3),
#  (1, 'Neighbors Charade', 2),
#  (1, 'Nemo Campus', 2),
#  (1, 'Network Peak', 4),
#  (1, 'Newton Labyrinth', 2),
#  (1, 'Nightmare Chill', 3),
#  (1, 'None Spiking', 3),
#  (1, 'Northwest Polish', 3),
#  (1, 'Novocaine Flight', 3),
#  (1, 'Nuts Ties', 3),
#  (1, 'Oleander Clue', 3),
#  (1, 'Open African', 2),
#  (1, 'Operation Operation', 4),
#  (1, 'Orange Grapes', 3),
#  (1, 'Orient Closer', 3),
#  (1, 'Oscar Gold', 3),
#  (1, 'Others Soup', 3),
#  (1, 'Outbreak Divine', 3),
#  (1, 'Outfield Massacre', 3),
#  (1, 'Outlaw Hanky', 4),
#  (1, 'Oz Liaisons', 2),
#  (1, 'Pacific Amistad', 2),
#  (1, 'Packer Madigan', 2),
#  (1, 'Pajama Jawbreaker', 4),
#  (1, 'Panic Club', 2),
#  (1, 'Panky Submarine', 2),
#  (1, 'Panther Reds', 3),
#  (1, 'Paradise Sabrina', 4),
#  (1, 'Party Knock', 2),
#  (1, 'Past Suicides', 4),
#  (1, 'Paths Control', 2),
#  (1, 'Patient Sister', 3),
#  (1, 'Patriot Roman', 2),
#  (1, 'Patton Interview', 4),
#  (1, 'Paycheck Wait', 3),
#  (1, 'Peach Innocent', 2),
#  (1, 'Peak Forever', 2),
#  (1, 'Pelican Comforts', 4),
#  (1, 'Perfect Groove', 2),
#  (1, 'Personal Ladybugs', 2),
#  (1, 'Pet Haunting', 3),
#  (1, 'Phantom Glory', 2),
#  (1, 'Philadelphia Wife', 2),
#  (1, 'Pianist Outfield', 3),
#  (1, 'Pickup Driving', 4),
#  (1, 'Pilot Hoosiers', 2),
#  (1, 'Pinocchio Simon', 2),
#  (1, 'Pirates Roxanne', 3),
#  (1, 'Pittsburgh Hunchback', 3),
#  (1, 'Pity Bound', 4),
#  (1, 'Pluto Oleander', 4),
#  (1, 'Pocus Pulp', 3),
#  (1, 'Pollock Deliverance', 4),
#  (1, 'Pond Seattle', 4),
#  (1, 'Poseidon Forever', 3),
#  (1, 'Potter Connecticut', 2),
#  (1, 'Prejudice Oleander', 4),
#  (1, 'President Bang', 2),
#  (1, 'Pride Alamo', 2),
#  (1, 'Primary Glass', 4),
#  (1, 'Princess Giant', 4),
#  (1, 'Private Drop', 2),
#  (1, 'Pulp Beverly', 4),
#  (1, 'Pure Runner', 2),
#  (1, 'Purple Movie', 4),
#  (1, 'Queen Luke', 2),
#  (1, 'Quest Mussolini', 2),
#  (1, 'Quills Bull', 2),
#  (1, 'Racer Egg', 2),
#  (1, 'Rage Games', 4),
#  (1, 'Range Moonwalker', 4),
#  (1, 'Reap Unfaithful', 2),
#  (1, 'Rear Trading', 2),
#  (1, 'Records Zorro', 2),
#  (1, 'Redemption Comforts', 3),
#  (1, 'Reds Pocus', 2),
#  (1, 'Reef Salute', 2),
#  (1, 'Reign Gentlemen', 4),
#  (1, 'Remember Diary', 2),
#  (1, 'Requiem Tycoon', 3),
#  (1, 'Resurrection Silverado', 2),
#  (1, 'Reunion Witches', 3),
#  (1, 'Ridgemont Submarine', 4),
#  (1, 'Rings Heartbreakers', 4),
#  (1, 'River Outlaw', 4),
#  (1, 'Road Roxanne', 2),
#  (1, 'Robbers Joon', 3),
#  (1, 'Robbery Bright', 4),
#  (1, 'Rock Instinct', 2),
#  (1, 'Rocketeer Mother', 4),
#  (1, 'Rocky War', 2),
#  (1, 'Roman Punk', 4),
#  (1, 'Room Roman', 2),
#  (1, 'Roots Remember', 2),
#  (1, 'Roses Treasure', 4),
#  (1, 'Rouge Squad', 2),
#  (1, 'Roxanne Rebel', 2),
#  (1, 'Rugrats Shakespeare', 4),
#  (1, 'Rules Human', 2),
#  (1, 'Run Pacific', 3),
#  (1, 'Rush Goodfellas', 4),
#  (1, 'Sabrina Midnight', 4),
#  (1, 'Sagebrush Clueless', 3),
#  (1, 'Salute Apollo', 2),
#  (1, 'Samurai Lion', 3),
#  (1, 'Satisfaction Confidential', 3),
#  (1, 'Saturday Lambs', 4),
#  (1, 'Saturn Name', 4),
#  (1, 'Savannah Town', 3),
#  (1, 'Scalawag Duck', 4),
#  (1, 'Scarface Bang', 3),
#  (1, 'Scorpion Apollo', 3),
#  (1, 'Sea Virgin', 4),
#  (1, 'Seabiscuit Punk', 4),
#  (1, 'Searchers Wait', 4),
#  (1, 'Seattle Expecations', 3),
#  (1, 'Secret Groundhog', 2),
#  (1, 'Secretary Rouge', 3),
#  (1, 'Secrets Paradise', 4),
#  (1, 'Shakespeare Saddle', 3),
#  (1, 'Shane Darkness', 4),
#  (1, 'Shanghai Tycoon', 3),
#  (1, 'Shawshank Bubble', 4),
#  (1, 'Shepherd Midsummer', 3),
#  (1, 'Shining Roses', 3),
#  (1, 'Ship Wonderland', 2),
#  (1, 'Shock Cabin', 4),
#  (1, 'Shootist Superfly', 4),
#  (1, 'Show Lord', 2),
#  (1, 'Shrunk Divine', 4),
#  (1, 'Side Ark', 2),
#  (1, 'Siege Madre', 4),
#  (1, 'Sierra Divide', 2),
#  (1, 'Silence Kane', 2),
#  (1, 'Silverado Goldfinger', 2),
#  (1, 'Simon North', 2),
#  (1, 'Sinners Atlantis', 2),
#  (1, 'Slacker Liaisons', 4),
#  (1, 'Sleeping Suspects', 4),
#  (1, 'Sleepless Monsoon', 2),
#  (1, 'Sleepy Japanese', 3),
#  (1, 'Sleuth Orient', 3),
#  (1, 'Slums Duck', 4),
#  (1, 'Smile Earring', 3),
#  (1, 'Smoking Barbarella', 3),
#  (1, 'Snatch Slipper', 3),
#  (1, 'Snatchers Montezuma', 3),
#  (1, 'Snowman Rollercoaster', 4),
#  (1, 'Soldiers Evolution', 2),
#  (1, 'Something Duck', 3),
#  (1, 'Song Hedwig', 3),
#  (1, 'Sons Interview', 4),
#  (1, 'South Wait', 3),
#  (1, 'Speakeasy Date', 3),
#  (1, 'Spice Sorority', 2),
#  (1, 'Spinal Rocky', 2),
#  (1, 'Spirited Casualties', 3),
#  (1, 'Splash Gump', 4),
#  (1, 'Splendor Patton', 3),
#  (1, 'Spy Mile', 4),
#  (1, 'Squad Fish', 3),
#  (1, 'Stagecoach Armageddon', 2),
#  (1, 'Stampede Disturbing', 4),
#  (1, 'Star Operation', 3),
#  (1, 'State Wasteland', 2),
#  (1, 'Steel Santa', 4),
#  (1, 'Steers Armageddon', 2),
#  (1, 'Stepmom Dream', 4),
#  (1, 'Sting Personal', 4),
#  (1, 'Stone Fire', 3),
#  (1, 'Storm Happiness', 4),
#  (1, 'Story Side', 3),
#  (1, 'Straight Hours', 3),
#  (1, 'Strangelove Desire', 4),
#  (1, 'Stranger Strangers', 3),
#  (1, 'Streak Ridgemont', 2),
#  (1, 'Streetcar Intentions', 4),
#  (1, 'Strictly Scarface', 3),
#  (1, 'Sugar Wonka', 3),
#  (1, 'Suit Walls', 3),
#  (1, 'Summer Scarface', 3),
#  (1, 'Sun Confessions', 4),
#  (1, 'Sundance Invasion', 4),
#  (1, 'Sunrise League', 4),
#  (1, 'Super Wyoming', 4),
#  (1, 'Superfly Trip', 3),
#  (1, 'Suspects Quills', 4),
#  (1, 'Swarm Gold', 4),
#  (1, 'Sweden Shining', 2),
#  (1, 'Sweethearts Suspects', 4),
#  (1, 'Talented Homicide', 3),
#  (1, 'Tarzan Videotape', 2),
#  (1, 'Taxi Kick', 3),
#  (1, 'Telegraph Voyage', 4),
#  (1, 'Telemark Heartbreakers', 4),
#  (1, 'Tenenbaums Command', 4),
#  (1, 'Texas Watch', 2),
#  (1, 'Theory Mermaid', 4),
#  (1, 'Thief Pelican', 4),
#  (1, 'Thin Sagebrush', 4),
#  (1, 'Ties Hunger', 3),
#  (1, 'Tights Dawn', 3),
#  (1, 'Timberland Sky', 3),
#  (1, 'Titanic Boondock', 3),
#  (1, 'Titans Jerk', 4),
#  (1, 'Tomatoes Hellfighters', 3),
#  (1, 'Tomorrow Hustler', 4),
#  (1, 'Tootsie Pilot', 2),
#  (1, 'Torque Bound', 4),
#  (1, 'Tourist Pelican', 3),
#  (1, 'Towers Hurricane', 3),
#  (1, 'Town Ark', 2),
#  (1, 'Tracy Cider', 4),
#  (1, 'Trading Pinocchio', 4),
#  (1, 'Train Bunch', 2),
#  (1, 'Trainspotting Strangers', 3),
#  (1, 'Tramp Others', 2),
#  (1, 'Translation Summer', 4),
#  (1, 'Trap Guys', 2),
#  (1, 'Trip Newton', 4),
#  (1, 'Trojan Tomorrow', 3),
#  (1, 'Troopers Metal', 4),
#  (1, 'Trouble Date', 2),
#  (1, 'Truman Crazy', 4),
#  (1, 'Turn Star', 2),
#  (1, 'Tuxedo Mile', 3),
#  (1, 'Tycoon Gathering', 4),
#  (1, 'Unbreakable Karate', 3),
#  (1, 'Uncut Suicides', 2),
#  (1, 'Undefeated Dalmations', 3),
#  (1, 'Unforgiven Zoolander', 2),
#  (1, 'United Pilot', 3),
#  (1, 'Uprising Uptown', 4),
#  (1, 'Uptown Young', 3),
#  (1, 'Usual Untouchables', 4),
#  (1, 'Vacation Boondock', 3),
#  (1, 'Valley Packer', 2),
#  (1, 'Vampire Whale', 3),
#  (1, 'Vanishing Rocky', 2),
#  (1, 'Varsity Trip', 2),
#  (1, 'Velvet Terminator', 4),
#  (1, 'Victory Academy', 3),
#  (1, 'Videotape Arsenic', 4),
#  (1, 'Vietnam Smoochy', 2),
#  (1, 'Virgin Daisy', 2),
#  (1, 'Virginian Pluto', 4),
#  (1, 'Vision Torque', 2),
#  (1, 'Voice Peach', 2),
#  (1, 'Volcano Texas', 4),
#  (1, 'Voyage Legally', 3),
#  (1, 'Wagon Jaws', 3),
#  (1, 'Wait Cider', 4),
#  (1, 'Wanda Chamber', 4),
#  (1, 'War Notting', 3),
#  (1, 'Wardrobe Phantom', 3),
#  (1, 'Warlock Werewolf', 2),
#  (1, 'Wash Heavenly', 3),
#  (1, 'Wasteland Divine', 4),
#  (1, 'Watch Tracy', 2),
#  (1, 'Waterfront Deliverance', 3),
#  (1, 'Watership Frontier', 2),
#  (1, 'Wedding Apollo', 2),
#  (1, 'Weekend Personal', 3),
#  (1, 'Werewolf Lola', 3),
#  (1, 'West Lion', 4),
#  (1, 'Westward Seabiscuit', 3),
#  (1, 'Whale Bikini', 4),
#  (1, 'Whisperer Giant', 3),
#  (1, 'Wife Turn', 4),
#  (1, 'Wild Apollo', 2),
#  (1, 'Willow Tracy', 2),
#  (1, 'Wind Phantom', 2),
#  (1, 'Wisdom Worker', 3),
#  (1, 'Witches Panic', 4),
#  (1, 'Wizard Coldblooded', 3),
#  (1, 'Wolves Desire', 3),
#  (1, 'Women Dorado', 3),
#  (1, 'Won Dares', 3),
#  (1, 'Wonderful Drop', 2),
#  (1, 'Wonderland Christmas', 4),
#  (1, 'Wonka Sea', 4),
#  (1, 'Words Hunter', 2),
#  (1, 'Worker Tarzan', 3),
#  (1, 'Working Microcosmos', 4),
#  (1, 'Worst Banger', 2),
#  (1, 'Wrong Behavior', 4),
#  (1, 'Wyoming Storm', 3),
#  (1, 'Yentl Idaho', 4),
#  (1, 'Young Language', 2),
#  (1, 'Youth Kick', 2),
#  (1, 'Zoolander Fiction', 2),
#  (1, 'Zorro Ark', 4),
#  (2, 'Academy Dinosaur', 4),
#  (2, 'Ace Goldfinger', 3),
#  (2, 'Adaptation Holes', 4),
#  (2, 'Affair Prejudice', 3),
#  (2, 'African Egg', 3),
#  (2, 'Agent Truman', 3),
#  (2, 'Airplane Sierra', 3),
#  (2, 'Airport Pollock', 4),
#  (2, 'Alabama Devil', 2),
#  (2, 'Aladdin Calendar', 3),
#  (2, 'Alamo Videotape', 3),
#  (2, 'Alaska Phantom', 4),
#  (2, 'Ali Forever', 4),
#  (2, 'Alien Center', 4),
#  (2, 'Alley Evolution', 2),
#  (2, 'Alone Trip', 3),
#  (2, 'Alter Victory', 3),
#  (2, 'Amadeus Holy', 2),
#  (2, 'American Circus', 4),
#  (2, 'Amistad Midsummer', 3),
#  (2, 'Anaconda Confessions', 2),
#  (2, 'Angels Life', 2),
#  (2, 'Annie Identity', 3),
#  (2, 'Apache Divine', 4),
#  (2, 'Apocalypse Flamingos', 2),
#  (2, 'Arabia Dogma', 4),
#  (2, 'Arachnophobia Rollercoaster', 3),
#  (2, 'Arizona Bang', 3),
#  (2, 'Armageddon Lost', 4),
#  (2, 'Army Flintstones', 4),
#  (2, 'Artist Coldblooded', 4),
#  (2, 'Atlantis Cause', 4),
#  (2, 'Attacks Hate', 3),
#  (2, 'Attraction Newton', 2),
#  (2, 'Autumn Crow', 3),
#  (2, 'Baby Hall', 2),
#  (2, 'Backlash Undefeated', 2),
#  (2, 'Badman Dawn', 3),
#  (2, 'Baked Cleopatra', 2),
#  (2, 'Balloon Homeward', 4),
#  (2, 'Ballroom Mockingbird', 2),
#  (2, 'Banger Pinocchio', 2),
#  (2, 'Barbarella Streetcar', 2),
#  (2, 'Barefoot Manchurian', 2),
#  (2, 'Basic Easy', 3),
#  (2, 'Beach Heartbreakers', 4),
#  (2, 'Bear Graceland', 2),
#  (2, 'Beauty Grease', 2),
#  (2, 'Bed Highball', 2),
#  (2, 'Bedazzled Married', 2),
#  (2, 'Beethoven Exorcist', 3),
#  (2, 'Behavior Runaway', 4),
#  (2, 'Berets Agent', 4),
#  (2, 'Betrayed Rear', 2),
#  (2, 'Beverly Outlaw', 4),
#  (2, 'Bikini Borrowers', 2),
#  (2, 'Bilko Anonymous', 4),
#  (2, 'Bill Others', 2),
#  (2, 'Bingo Talented', 4),
#  (2, 'Birch Antitrust', 2),
#  (2, 'Bird Independence', 3),
#  (2, 'Birds Perdition', 2),
#  (2, 'Blackout Private', 4),
#  (2, 'Blade Polish', 3),
#  (2, 'Blues Instinct', 2),
#  (2, 'Bonnie Holocaust', 4),
#  (2, 'Boogie Amelie', 4),
#  (2, 'Born Spinal', 4),
#  (2, 'Borrowers Bedazzled', 3),
#  (2, 'Boulevard Mob', 3),
#  (2, 'Bound Cheaper', 4),
#  (2, 'Bowfinger Gables', 2),
#  (2, 'Brannigan Sunrise', 3),
#  (2, 'Breakfast Goldfinger', 3),
#  (2, 'Bride Intrigue', 2),
#  (2, 'Bringing Hysterical', 3),
#  (2, 'Brooklyn Desert', 2),
#  (2, 'Brotherhood Blanket', 2),
#  (2, 'Bubble Grosse', 2),
#  (2, 'Bucket Brotherhood', 4),
#  (2, 'Bugsy Song', 3),
#  (2, 'Bull Shawshank', 3),
#  (2, 'Bunch Minds', 2),
#  (2, 'Butterfly Chocolat', 4),
#  (2, 'Caddyshack Jedi', 4),
#  (2, 'Calendar Gunfight', 3),
#  (2, 'California Birds', 4),
#  (2, 'Camelot Vacation', 3),
#  (2, 'Campus Remember', 4),
#  (2, 'Candidate Perdition', 4),
#  (2, 'Candles Grapes', 2),
#  (2, 'Canyon Stock', 2),
#  (2, 'Caper Motions', 4),
#  (2, 'Carol Texas', 3),
#  (2, 'Carrie Bunch', 3),
#  (2, 'Casablanca Super', 3),
#  (2, 'Casper Dragonfly', 3),
#  (2, 'Cassidy Wyoming', 2),
#  (2, 'Casualties Encino', 3),
#  (2, 'Cat Coneheads', 4),
#  (2, 'Cause Date', 3),
#  (2, 'Celebrity Horn', 4),
#  (2, 'Center Dinosaur', 2),
#  (2, 'Chainsaw Uptown', 2),
#  (2, 'Chamber Italian', 2),
#  (2, 'Champion Flatliners', 3),
#  (2, 'Chance Resurrection', 4),
#  (2, 'Charade Duffel', 4),
#  (2, 'Chariots Conspiracy', 3),
#  (2, 'Chasing Fight', 2),
#  (2, 'Cheaper Clyde', 3),
#  (2, 'Chicago North', 2),
#  (2, 'Chicken Hellfighters', 2),
#  (2, 'Chill Luck', 3),
#  (2, 'Chisum Behavior', 3),
#  (2, 'Chocolat Harry', 3),
#  (2, 'Christmas Moonshine', 3),
#  (2, 'Cider Desire', 4),
#  (2, 'Cincinatti Whisperer', 2),
#  (2, 'Clash Freddy', 4),
#  (2, 'Cleopatra Devil', 3),
#  (2, 'Clerks Angels', 2),
#  (2, 'Clockwork Paradise', 3),
#  (2, 'Clones Pinocchio', 3),
#  (2, 'Closer Bang', 3),
#  (2, 'Club Graffiti', 3),
#  (2, 'Clueless Bucket', 4),
#  (2, 'Clyde Theory', 3),
#  (2, 'Coast Rainbow', 3),
#  (2, 'Coldblooded Darling', 2),
#  (2, 'Color Philadelphia', 2),
#  (2, 'Coma Head', 3),
#  (2, 'Comforts Rush', 2),
#  (2, 'Command Darling', 4),
#  (2, 'Coneheads Smoochy', 3),
#  (2, 'Confessions Maguire', 2),
#  (2, 'Confidential Interview', 4),
#  (2, 'Confused Candles', 3),
#  (2, 'Congeniality Quest', 4),
#  (2, 'Connecticut Tramp', 3),
#  (2, 'Conspiracy Spirit', 2),
#  (2, 'Contact Anonymous', 4),
#  (2, 'Conversation Downhill', 3),
#  (2, 'Core Suit', 3),
#  (2, 'Craft Outfield', 2),
#  (2, 'Cranes Reservoir', 3),
#  (2, 'Creatures Shakespeare', 4),
#  (2, 'Creepers Kane', 4),
#  (2, 'Crooked Frogmen', 3),
#  (2, 'Crossroads Casualties', 4),
#  (2, 'Crow Grease', 2),
#  (2, 'Cupboard Sinners', 4),
#  (2, 'Curtain Videotape', 4),
#  (2, 'Daisy Menagerie', 4),
#  (2, 'Dalmations Sweden', 2),
#  (2, 'Dancing Fever', 4),
#  (2, 'Darko Dorado', 3),
#  (2, 'Darn Forrester', 2),
#  (2, 'Daughter Madigan', 4),
#  (2, 'Dawn Pond', 3),
#  (2, 'Day Unfaithful', 3),
#  (2, 'Deceiver Betrayed', 3),
#  (2, 'Deer Virginian', 4),
#  (2, 'Desert Poseidon', 4),
#  (2, 'Desire Alien', 2),
#  (2, 'Destiny Saturday', 3),
#  (2, 'Details Packer', 2),
#  (2, 'Detective Vision', 4),
#  (2, 'Devil Desire', 2),
#  (2, 'Dinosaur Secretary', 4),
#  (2, 'Dirty Ace', 2),
#  (2, 'Disciple Mother', 2),
#  (2, 'Disturbing Scarface', 3),
#  (2, 'Divide Monster', 4),
#  (2, 'Divine Resurrection', 4),
#  (2, 'Dogma Family', 4),
#  (2, 'Dolls Rage', 3),
#  (2, 'Doom Dancing', 3),
#  (2, 'Doors President', 4),
#  (2, 'Dorado Notting', 3),
#  (2, 'Double Wrath', 4),
#  (2, 'Doubtfire Labyrinth', 3),
#  (2, 'Downhill Enough', 4),
#  (2, 'Dozen Lion', 2),
#  (2, 'Dracula Crystal', 4),
#  (2, 'Dragon Squad', 4),
#  (2, 'Dragonfly Strangers', 3),
#  (2, 'Dream Pickup', 3),
#  (2, 'Drifter Commandments', 2),
#  (2, 'Driver Annie', 3),
#  (2, 'Driving Polish', 2),
#  (2, 'Drop Waterfront', 3),
#  (2, 'Drumline Cyclone', 3),
#  (2, 'Drums Dynamite', 4),
#  (2, 'Dude Blindness', 4),
#  (2, 'Dumbo Lust', 2),
#  (2, 'Durham Panky', 3),
#  (2, 'Dwarfs Alter', 2),
#  (2, 'Dynamite Tarzan', 4),
#  (2, 'Eagles Panky', 2),
#  (2, 'Early Home', 2),
#  (2, 'Earring Instinct', 4),
#  (2, 'Earth Vision', 4),
#  (2, 'Easy Gladiator', 2),
#  (2, 'Effect Gladiator', 3),
#  (2, 'Egg Igby', 4),
#  (2, 'Egypt Tenenbaums', 2),
#  (2, 'Empire Malkovich', 2),
#  (2, 'Encino Elf', 4),
#  (2, 'Encounters Curtain', 3),
#  (2, 'Enemy Odds', 4),
#  (2, 'English Bulworth', 4),
#  (2, 'Enough Raging', 3),
#  (2, 'Entrapment Satisfaction', 2),
#  (2, 'Escape Metropolis', 4),
#  (2, 'Excitement Eve', 3),
#  (2, 'Exorcist Sting', 3),
#  (2, 'Expecations Natural', 3),
#  (2, 'Expendable Stallion', 4),
#  (2, 'Extraordinary Conquerer', 2),
#  (2, 'Eyes Driving', 3),
#  (2, 'Falcon Volume', 4),
#  (2, 'Family Sweet', 4),
#  (2, 'Fantasia Park', 4),
#  (2, 'Fantasy Troopers', 2),
#  (2, 'Fargo Gandhi', 2),
#  (2, 'Fatal Haunted', 3),
#  (2, 'Fellowship Autumn', 3),
#  (2, 'Ferris Mother', 2),
#  (2, 'Feud Frogmen', 4),
#  (2, 'Fiction Christmas', 4),
#  (2, 'Fiddler Lost', 3),
#  (2, 'Fidelity Devil', 2),
#  (2, 'Fight Jawbreaker', 4),
#  (2, 'Finding Anaconda', 3),
#  (2, 'Fire Wolves', 2),
#  (2, 'Fireball Philadelphia', 3),
#  (2, 'Fish Opus', 4),
#  (2, 'Flamingos Connecticut', 4),
#  (2, 'Flatliners Killer', 2),
#  (2, 'Flight Lies', 4),
#  ...]

# %% [markdown]
# ## Question 7
# Customer name and email who eligible for the platinum credit card (transaction payment >= 40)

# %%
# %%sql
#
# SELECT concat(c.first_name,' ', c.last_name) as fullname, c.email, count(p.payment_id) as transaction_payment
#     FROM customer c
#     INNER JOIN payment p
#     ON c.customer_id = p.customer_id
#     GROUP BY c.customer_id
#     HAVING count(p.payment_id) >= 40
#     ORDER BY count(p.payment_id) desc;
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 3 rows affected.
# [('Eleanor Hunt', 'eleanor.hunt@sakilacustomer.org', 45),
#  ('Karl Seal', 'karl.seal@sakilacustomer.org', 42),
#  ('Clara Shaw', 'clara.shaw@sakilacustomer.org', 40)]
