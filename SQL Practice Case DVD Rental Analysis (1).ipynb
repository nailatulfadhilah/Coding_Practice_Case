# %% [markdown]
# # DVD Rental Analysis
# The analysis begins with inputting the database and understanding the schema of the database. The database can be downloaded at <a href="https://www.postgresqltutorial.com/postgresql-sample-database/" target="_blank">this link</a>. Here is a scheme that helps in understanding the ERM (Entity Relationship Model):
# <img src="https://sp.postgresqltutorial.com/wp-content/uploads/2018/03/dvd-rental-sample-database-diagram.png" alt="Scheme" width="460" height="345">

# %%
#Install the libraries that will be used
# !pip install ipython-sql
# !pip install sqlalchemy
# !pip install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython-sql) (1.3.18)
# Requirement already satisfied: six in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: prettytable<1 in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: sqlparse in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython-sql) (0.3.1)
# Requirement already satisfied: ipython>=1.0 in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython-sql) (7.16.1)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.5)
# Requirement already satisfied: decorator in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.3)
# Requirement already satisfied: jedi>=0.10 in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.17.1)
# Requirement already satisfied: pygments in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (4.3.3)
# Requirement already satisfied: pickleshare in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (49.2.0.post20200714)
# Requirement already satisfied: backcall in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: sqlalchemy in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (1.3.18)
# Requirement already satisfied: psycopg2 in c:\users\nailatul fadhilah\anaconda3\lib\site-packages (2.8.5)

# %%
#load ipython-sql
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
#Import function create_engine() from sqlalchemy because we only need that
from sqlalchemy import create_engine
#Import pandas
import pandas as pd

# %%
#Connect ipython-sql to database
# %sql postgresql://postgres:1691299postgres@localhost/DVDrental

# %%
#Called engine using the create_engine() function
engine = create_engine('postgresql://postgres:1691299postgres@localhost/DVDrental')

# %% [markdown]
# ## Question 1
# Recommendations the film about 'astronaut'

# %%
pd.read_sql_query("select * from film where fulltext @@ to_tsquery('astronaut')", con = engine)
# Out:
#     film_id               title  \
# 0        16     Alley Evolution
# 1        21     American Circus
# 2        25         Angels Life
# 3        27     Anonymous Human
# 4        70    Bikini Borrowers
# ..      ...                 ...
# 73      953          Wait Cider
# 74      958    Wardrobe Phantom
# 75      975        Willow Tracy
# 76      990  World Leathernecks
# 77      995         Yentl Idaho
#
#                                           description  release_year  \
# 0   A Fast-Paced Drama of a Robot And a Composer w...          2006
# 1   A Insightful Drama of a Girl And a Astronaut w...          2006
# 2   A Thoughtful Display of a Woman And a Astronau...          2006
# 3   A Amazing Reflection of a Database Administrat...          2006
# 4   A Astounding Drama of a Astronaut And a Cat wh...          2006
# ..                                                ...           ...
# 73  A Intrepid Epistle of a Woman And a Forensic P...          2006
# 74  A Action-Packed Display of a Mad Cow And a Ast...          2006
# 75  A Brilliant Panorama of a Boat And a Astronaut...          2006
# 76  A Unbelieveable Tale of a Pioneer And a Astron...          2006
# 77  A Amazing Display of a Robot And a Astronaut w...          2006
#
#     language_id  rental_duration  rental_rate  length  replacement_cost  \
# 0             1                6         2.99     180             23.99
# 1             1                3         4.99     129             17.99
# 2             1                3         2.99      74             15.99
# 3             1                7         0.99     179             12.99
# 4             1                7         4.99     142             26.99
# ..          ...              ...          ...     ...               ...
# 73            1                3         0.99     112              9.99
# 74            1                6         2.99     178             19.99
# 75            1                6         2.99     137             22.99
# 76            1                3         0.99     171             13.99
# 77            1                5         4.99      86             11.99
#
#    rating             last_update  \
# 0   NC-17 2013-05-26 14:50:58.951
# 1       R 2013-05-26 14:50:58.951
# 2       G 2013-05-26 14:50:58.951
# 3   NC-17 2013-05-26 14:50:58.951
# 4   NC-17 2013-05-26 14:50:58.951
# ..    ...                     ...
# 73  PG-13 2013-05-26 14:50:58.951
# 74      G 2013-05-26 14:50:58.951
# 75      R 2013-05-26 14:50:58.951
# 76  PG-13 2013-05-26 14:50:58.951
# 77      R 2013-05-26 14:50:58.951
#
#                                special_features  \
# 0                      [Trailers, Commentaries]
# 1             [Commentaries, Behind the Scenes]
# 2                                    [Trailers]
# 3           [Deleted Scenes, Behind the Scenes]
# 4                [Commentaries, Deleted Scenes]
# ..                                          ...
# 73                                   [Trailers]
# 74                     [Trailers, Commentaries]
# 75  [Trailers, Commentaries, Behind the Scenes]
# 76                [Trailers, Behind the Scenes]
# 77     [Trailers, Commentaries, Deleted Scenes]
#
#                                              fulltext
# 0   'alley':1 'astronaut':18 'battl':16 'compos':1...
# 1   'administr':17 'american':1 'astronaut':11 'ci...
# 2   'angel':1 'astronaut':11 'battl':14 'berlin':1...
# 3   'administr':9,18 'amaz':4 'anonym':1 'astronau...
# 4   'astound':4 'astronaut':8 'bikini':1 'borrow':...
# ..                                                ...
# 73  'astronaut':17 'cider':2 'epistl':5 'forens':1...
# 74  'action':5 'action-pack':4 'ancient':21 'astro...
# 75  'astronaut':11 'boat':8 'brilliant':4 'challen...
# 76  'abandon':19 'amus':20 'astronaut':11 'leather...
# 77  'amaz':4 'astronaut':11 'berlin':18 'display':...
#
# [78 rows x 13 columns]

# %% [markdown]
# Number of films about 'astronaut'

# %%
# %%sql
#
# SELECT count(*) AS number_of_films_about_astronout
#     FROM film
#     WHERE fulltext @@ to_tsquery('astronaut');
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 1 rows affected.
# [(78,)]

# %% [markdown]
# ## QUESTION 2
# Films which have rating 'R' and replacement cost between \\$5 and \\$15

# %%
# %%sql
#
# SELECT title, rating,replacement_cost
#     FROM film
#     where (rating = 'R') AND (replacement_cost between 5 AND 15);
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 52 rows affected.
# [('Alone Trip', 'R', Decimal('14.99')),
#  ('Anaconda Confessions', 'R', Decimal('9.99')),
#  ('Apocalypse Flamingos', 'R', Decimal('11.99')),
#  ('Boogie Amelie', 'R', Decimal('11.99')),
#  ('Boulevard Mob', 'R', Decimal('11.99')),
#  ('Candidate Perdition', 'R', Decimal('10.99')),
#  ('Chocolate Duck', 'R', Decimal('13.99')),
#  ('Closer Bang', 'R', Decimal('12.99')),
#  ('Clueless Bucket', 'R', Decimal('13.99')),
#  ('Commandments Express', 'R', Decimal('13.99')),
#  ('Conversation Downhill', 'R', Decimal('14.99')),
#  ('Deliverance Mulholland', 'R', Decimal('9.99')),
#  ('Devil Desire', 'R', Decimal('12.99')),
#  ('Doom Dancing', 'R', Decimal('13.99')),
#  ('Durham Panky', 'R', Decimal('14.99')),
#  ('Fight Jawbreaker', 'R', Decimal('13.99')),
#  ('Finding Anaconda', 'R', Decimal('10.99')),
#  ('Frida Slipper', 'R', Decimal('11.99')),
#  ('Galaxy Sweethearts', 'R', Decimal('13.99')),
#  ('Giant Troopers', 'R', Decimal('10.99')),
#  ('Go Purple', 'R', Decimal('12.99')),
#  ('Greedy Roots', 'R', Decimal('14.99')),
#  ('Highball Potter', 'R', Decimal('10.99')),
#  ('Holocaust Highball', 'R', Decimal('12.99')),
#  ('House Dynamite', 'R', Decimal('13.99')),
#  ('Jeopardy Encino', 'R', Decimal('12.99')),
#  ('Jet Neighbors', 'R', Decimal('14.99')),
#  ('Killer Innocent', 'R', Decimal('11.99')),
#  ('Kissing Dolls', 'R', Decimal('9.99')),
#  ('Lock Rear', 'R', Decimal('10.99')),
#  ('Madison Trap', 'R', Decimal('11.99')),
#  ('Oz Liaisons', 'R', Decimal('14.99')),
#  ('Pajama Jawbreaker', 'R', Decimal('14.99')),
#  ('Pluto Oleander', 'R', Decimal('9.99')),
#  ('Prix Undefeated', 'R', Decimal('13.99')),
#  ('Purple Movie', 'R', Decimal('9.99')),
#  ('Road Roxanne', 'R', Decimal('12.99')),
#  ('Roxanne Rebel', 'R', Decimal('9.99')),
#  ('Shepherd Midsummer', 'R', Decimal('14.99')),
#  ('Shrunk Divine', 'R', Decimal('14.99')),
#  ('Sling Luke', 'R', Decimal('10.99')),
#  ('Soup Wisdom', 'R', Decimal('12.99')),
#  ('Tights Dawn', 'R', Decimal('14.99')),
#  ('Streetcar Intentions', 'R', Decimal('11.99')),
#  ('Suit Walls', 'R', Decimal('12.99')),
#  ('Sun Confessions', 'R', Decimal('9.99')),
#  ('Terminator Club', 'R', Decimal('11.99')),
#  ('Unfaithful Kill', 'R', Decimal('12.99')),
#  ('Velvet Terminator', 'R', Decimal('14.99')),
#  ('Wind Phantom', 'R', Decimal('12.99')),
#  ('Wisdom Worker', 'R', Decimal('12.99')),
#  ('Yentl Idaho', 'R', Decimal('11.99'))]

# %% [markdown]
# Number of films with rating 'R' and replacement cost between $5 and $15

# %%
# %%sql
#
# SELECT count(film_id) AS film_rating_r_rc_5_and_15
#     FROM film where (rating = 'R') AND (replacement_cost between 5 and 15);
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 1 rows affected.
# [(52,)]

# %% [markdown]
# ## QUESTION 3
# The number of payment and the total amount for each staff

# %%
# %%sql
#
# SELECT staff_id, count(payment_id) AS payment, sum(amount) AS amount
#     FROM payment
#     GROUP BY staff_id
#     ORDER BY amount desc;
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 2 rows affected.
# [(2, 7304, Decimal('31059.92')), (1, 7292, Decimal('30252.12'))]

# %% [markdown]
# Name of staff, number of payment, and total amount for each staff

# %%
# %%sql
#
# SELECT concat(s.first_name, ' ', s.last_name) AS fullname, s.staff_id, count(p.payment_id) AS payment, sum(p.amount) AS amount
#     FROM payment p
#     INNER JOIN staff s
#     ON p.staff_id = s.staff_id
#     GROUP BY s.staff_id
#     ORDER BY amount desc;
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 2 rows affected.
# [('Jon Stephens', 2, 7304, Decimal('31059.92')),
#  ('Mike Hillyer', 1, 7292, Decimal('30252.12'))]

# %% [markdown]
# ## QUESTION 4
# The average of replacement cost of movies by rating

# %%
# %%sql
#
# SELECT rating, avg(replacement_cost) AS avg_replacement_cost
#     FROM film
#     GROUP BY rating
#     ORDER BY avg_replacement_cost desc;
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 5 rows affected.
# [('PG-13', Decimal('20.4025560538116592')),
#  ('R', Decimal('20.2310256410256410')),
#  ('NC-17', Decimal('20.1376190476190476')),
#  ('G', Decimal('20.1248314606741573')),
#  ('PG', Decimal('18.9590721649484536'))]

# %% [markdown]
# ## QUESTION 5
# 5 customers who have spent the most amount of money

# %%
# %%sql
#
# SELECT concat(c.first_name,' ', c.last_name) AS fullname, c.email, sum(p.amount) AS sum_amount
#     FROM customer c
#     INNER JOIN payment p
#     ON c.customer_id = p.customer_id
#     GROUP BY c.customer_id
#     ORDER BY sum_amount desc
#     LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 5 rows affected.
# [('Eleanor Hunt', 'eleanor.hunt@sakilacustomer.org', Decimal('211.55')),
#  ('Karl Seal', 'karl.seal@sakilacustomer.org', Decimal('208.58')),
#  ('Marion Snyder', 'marion.snyder@sakilacustomer.org', Decimal('194.61')),
#  ('Rhonda Kennedy', 'rhonda.kennedy@sakilacustomer.org', Decimal('191.62')),
#  ('Clara Shaw', 'clara.shaw@sakilacustomer.org', Decimal('189.60'))]

# %% [markdown]
# ## QUESTION 6
# Number of copies of each movie in each store

# %%
# %%sql
#
# SELECT i.store_id, f.title, count(i.film_id) AS count_film
#     FROM inventory i
#     INNER JOIN film f
#     ON i.film_id = f.film_id
#     GROUP BY i.store_id, f.title
#     ORDER BY i.store_id, f.title;
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 1521 rows affected.
# [(1, 'Academy Dinosaur', 4),
#  (1, 'Affair Prejudice', 4),
#  (1, 'Agent Truman', 3),
#  (1, 'Airplane Sierra', 2),
#  (1, 'Alabama Devil', 3),
#  (1, 'Aladdin Calendar', 4),
#  (1, 'Alamo Videotape', 4),
#  (1, 'Alaska Phantom', 3),
#  (1, 'Alien Center', 2),
#  (1, 'Alley Evolution', 2),
#  (1, 'Alone Trip', 3),
#  (1, 'Alter Victory', 3),
#  (1, 'Amadeus Holy', 4),
#  (1, 'Amelie Hellfighters', 3),
#  (1, 'American Circus', 2),
#  (1, 'Amistad Midsummer', 4),
#  (1, 'Anaconda Confessions', 3),
#  (1, 'Analyze Hoosiers', 4),
#  (1, 'Angels Life', 4),
#  (1, 'Annie Identity', 2),
#  (1, 'Anonymous Human', 4),
#  (1, 'Anthem Luke', 3),
#  (1, 'Antitrust Tomatoes', 2),
#  (1, 'Anything Savannah', 2),
#  (1, 'Apache Divine', 4),
#  (1, 'Arachnophobia Rollercoaster', 4),
#  (1, 'Arizona Bang', 4),
#  (1, 'Armageddon Lost', 3),
#  (1, 'Atlantis Cause', 3),
#  (1, 'Attacks Hate', 2),
#  (1, 'Attraction Newton', 4),
#  (1, 'Backlash Undefeated', 2),
#  (1, 'Badman Dawn', 3),
#  (1, 'Baked Cleopatra', 3),
#  (1, 'Balloon Homeward', 2),
#  (1, 'Bang Kwai', 2),
#  (1, 'Banger Pinocchio', 3),
#  (1, 'Barbarella Streetcar', 4),
#  (1, 'Barefoot Manchurian', 3),
#  (1, 'Basic Easy', 4),
#  (1, 'Bear Graceland', 3),
#  (1, 'Beast Hunchback', 3),
#  (1, 'Beauty Grease', 4),
#  (1, 'Bedazzled Married', 2),
#  (1, 'Beneath Rush', 3),
#  (1, 'Berets Agent', 2),
#  (1, 'Betrayed Rear', 2),
#  (1, 'Beverly Outlaw', 4),
#  (1, 'Bikini Borrowers', 2),
#  (1, 'Bill Others', 4),
#  (1, 'Bingo Talented', 4),
#  (1, 'Birch Antitrust', 3),
#  (1, 'Birdcage Casper', 3),
#  (1, 'Birds Perdition', 4),
#  (1, 'Blackout Private', 3),
#  (1, 'Blade Polish', 3),
#  (1, 'Blanket Beverly', 4),
#  (1, 'Blindness Gun', 4),
#  (1, 'Blood Argonauts', 2),
#  (1, 'Blues Instinct', 3),
#  (1, 'Boiled Dares', 4),
#  (1, 'Boogie Amelie', 4),
#  (1, 'Borrowers Bedazzled', 3),
#  (1, 'Boulevard Mob', 3),
#  (1, 'Bound Cheaper', 4),
#  (1, 'Bowfinger Gables', 2),
#  (1, 'Braveheart Human', 2),
#  (1, 'Breakfast Goldfinger', 2),
#  (1, 'Breaking Home', 3),
#  (1, 'Bride Intrigue', 4),
#  (1, 'Bright Encounters', 3),
#  (1, 'Bringing Hysterical', 3),
#  (1, 'Brooklyn Desert', 4),
#  (1, 'Brotherhood Blanket', 4),
#  (1, 'Bucket Brotherhood', 4),
#  (1, 'Bull Shawshank', 2),
#  (1, 'Bulworth Commandments', 2),
#  (1, 'Butterfly Chocolat', 4),
#  (1, 'Cabin Flash', 4),
#  (1, 'Calendar Gunfight', 4),
#  (1, 'Camelot Vacation', 4),
#  (1, 'Campus Remember', 3),
#  (1, 'Candidate Perdition', 2),
#  (1, 'Candles Grapes', 4),
#  (1, 'Canyon Stock', 4),
#  (1, 'Caper Motions', 3),
#  (1, 'Caribbean Liberty', 3),
#  (1, 'Carol Texas', 3),
#  (1, 'Carrie Bunch', 4),
#  (1, 'Casablanca Super', 2),
#  (1, 'Cat Coneheads', 4),
#  (1, 'Cause Date', 3),
#  (1, 'Celebrity Horn', 2),
#  (1, 'Center Dinosaur', 4),
#  (1, 'Chainsaw Uptown', 4),
#  (1, 'Chamber Italian', 2),
#  (1, 'Chance Resurrection', 3),
#  (1, 'Chaplin License', 3),
#  (1, 'Chariots Conspiracy', 2),
#  (1, 'Chasing Fight', 4),
#  (1, 'Cheaper Clyde', 2),
#  (1, 'Chicago North', 3),
#  (1, 'Chicken Hellfighters', 3),
#  (1, 'Chill Luck', 4),
#  (1, 'Chitty Lock', 3),
#  (1, 'Chocolat Harry', 3),
#  (1, 'Christmas Moonshine', 3),
#  (1, 'Cider Desire', 2),
#  (1, 'Cincinatti Whisperer', 2),
#  (1, 'Circus Youth', 4),
#  (1, 'Citizen Shrek', 4),
#  (1, 'Clash Freddy', 3),
#  (1, 'Cleopatra Devil', 2),
#  (1, 'Clones Pinocchio', 2),
#  (1, 'Closer Bang', 4),
#  (1, 'Club Graffiti', 2),
#  (1, 'Clue Grail', 2),
#  (1, 'Clueless Bucket', 3),
#  (1, 'Coast Rainbow', 2),
#  (1, 'Coldblooded Darling', 3),
#  (1, 'Color Philadelphia', 4),
#  (1, 'Coma Head', 4),
#  (1, 'Comancheros Enemy', 2),
#  (1, 'Comforts Rush', 2),
#  (1, 'Command Darling', 2),
#  (1, 'Coneheads Smoochy', 4),
#  (1, 'Confessions Maguire', 3),
#  (1, 'Confidential Interview', 4),
#  (1, 'Confused Candles', 2),
#  (1, 'Congeniality Quest', 2),
#  (1, 'Connection Microcosmos', 2),
#  (1, 'Conquerer Nuts', 4),
#  (1, 'Contact Anonymous', 3),
#  (1, 'Control Anthem', 2),
#  (1, 'Conversation Downhill', 3),
#  (1, 'Core Suit', 2),
#  (1, 'Cowboy Doom', 2),
#  (1, 'Craft Outfield', 2),
#  (1, 'Crazy Home', 3),
#  (1, 'Creatures Shakespeare', 2),
#  (1, 'Crooked Frogmen', 3),
#  (1, 'Crossroads Casualties', 4),
#  (1, 'Crow Grease', 2),
#  (1, 'Cruelty Unforgiven', 2),
#  (1, 'Crusade Honey', 2),
#  (1, 'Cupboard Sinners', 4),
#  (1, 'Curtain Videotape', 4),
#  (1, 'Cyclone Family', 4),
#  (1, 'Daddy Pittsburgh', 3),
#  (1, 'Dalmations Sweden', 4),
#  (1, 'Dances None', 4),
#  (1, 'Dancing Fever', 4),
#  (1, 'Dangerous Uptown', 4),
#  (1, 'Dares Pluto', 3),
#  (1, 'Darkness War', 4),
#  (1, 'Darling Breaking', 2),
#  (1, 'Darn Forrester', 3),
#  (1, 'Date Speed', 4),
#  (1, 'Dawn Pond', 3),
#  (1, 'Day Unfaithful', 2),
#  (1, 'Deceiver Betrayed', 4),
#  (1, 'Deep Crusade', 4),
#  (1, 'Deer Virginian', 4),
#  (1, 'Desert Poseidon', 2),
#  (1, 'Desperate Trainspotting', 2),
#  (1, 'Destination Jerk', 3),
#  (1, 'Destiny Saturday', 2),
#  (1, 'Details Packer', 3),
#  (1, 'Detective Vision', 3),
#  (1, 'Devil Desire', 2),
#  (1, 'Diary Panic', 2),
#  (1, 'Dinosaur Secretary', 4),
#  (1, 'Dirty Ace', 3),
#  (1, 'Disciple Mother', 4),
#  (1, 'Disturbing Scarface', 4),
#  (1, 'Divide Monster', 2),
#  (1, 'Divorce Shining', 2),
#  (1, 'Doctor Grail', 2),
#  (1, 'Dogma Family', 4),
#  (1, 'Donnie Alley', 4),
#  (1, 'Doom Dancing', 2),
#  (1, 'Doors President', 2),
#  (1, 'Dorado Notting', 4),
#  (1, 'Double Wrath', 3),
#  (1, 'Downhill Enough', 3),
#  (1, 'Dracula Crystal', 2),
#  (1, 'Dragonfly Strangers', 2),
#  (1, 'Dream Pickup', 3),
#  (1, 'Drifter Commandments', 4),
#  (1, 'Driver Annie', 2),
#  (1, 'Driving Polish', 4),
#  (1, 'Duck Racer', 2),
#  (1, 'Duffel Apocalypse', 2),
#  (1, 'Durham Panky', 4),
#  (1, 'Dying Maker', 4),
#  (1, 'Dynamite Tarzan', 4),
#  (1, 'Eagles Panky', 4),
#  (1, 'Earring Instinct', 2),
#  (1, 'Earth Vision', 3),
#  (1, 'Easy Gladiator', 3),
#  (1, 'Edge Kissing', 4),
#  (1, 'Effect Gladiator', 4),
#  (1, 'Egg Igby', 3),
#  (1, 'Egypt Tenenbaums', 3),
#  (1, 'Element Freddy', 4),
#  (1, 'Elephant Trojan', 3),
#  (1, 'Elf Murder', 2),
#  (1, 'Elizabeth Shane', 2),
#  (1, 'Empire Malkovich', 4),
#  (1, 'Encino Elf', 2),
#  (1, 'Encounters Curtain', 3),
#  (1, 'Ending Crowds', 3),
#  (1, 'Enemy Odds', 3),
#  (1, 'English Bulworth', 3),
#  (1, 'Enough Raging', 2),
#  (1, 'Entrapment Satisfaction', 2),
#  (1, 'Escape Metropolis', 2),
#  (1, 'Eve Resurrection', 2),
#  (1, 'Everyone Craft', 3),
#  (1, 'Evolution Alter', 4),
#  (1, 'Excitement Eve', 3),
#  (1, 'Exorcist Sting', 2),
#  (1, 'Expecations Natural', 2),
#  (1, 'Expendable Stallion', 4),
#  (1, 'Express Lonely', 4),
#  (1, 'Eyes Driving', 2),
#  (1, 'Factory Dragon', 4),
#  (1, 'Falcon Volume', 2),
#  (1, 'Family Sweet', 4),
#  (1, 'Fantasia Park', 2),
#  (1, 'Fantasy Troopers', 4),
#  (1, 'Fargo Gandhi', 4),
#  (1, 'Fatal Haunted', 4),
#  (1, 'Feathers Metal', 3),
#  (1, 'Fellowship Autumn', 3),
#  (1, 'Ferris Mother', 2),
#  (1, 'Feud Frogmen', 2),
#  (1, 'Fever Empire', 2),
#  (1, 'Fiction Christmas', 3),
#  (1, 'Fidelity Devil', 4),
#  (1, 'Fight Jawbreaker', 2),
#  (1, 'Fireball Philadelphia', 4),
#  (1, 'Fish Opus', 3),
#  (1, 'Flamingos Connecticut', 3),
#  (1, 'Flash Wars', 4),
#  (1, 'Flatliners Killer', 4),
#  (1, 'Flintstones Happiness', 3),
#  (1, 'Flying Hook', 2),
#  (1, 'Fool Mockingbird', 4),
#  (1, 'Forrest Sons', 3),
#  (1, 'Forrester Comancheros', 4),
#  (1, 'Forward Temple', 4),
#  (1, 'Freaky Pocus', 2),
#  (1, 'Freddy Storm', 2),
#  (1, 'Freedom Cleopatra', 2),
#  (1, 'French Holiday', 3),
#  (1, 'Frida Slipper', 2),
#  (1, 'Frontier Cabin', 2),
#  (1, 'Frost Head', 4),
#  (1, 'Fugitive Maguire', 4),
#  (1, 'Full Flatliners', 2),
#  (1, 'Fury Murder', 3),
#  (1, 'Gables Metropolis', 3),
#  (1, 'Galaxy Sweethearts', 2),
#  (1, 'Games Bowfinger', 4),
#  (1, 'Gangs Pride', 4),
#  (1, 'Garden Island', 4),
#  (1, 'Gaslight Crusade', 3),
#  (1, 'Gentlemen Stage', 2),
#  (1, 'Ghost Groundhog', 3),
#  (1, 'Giant Troopers', 4),
#  (1, 'Gilmore Boiled', 4),
#  (1, 'Glass Dying', 4),
#  (1, 'Gleaming Jawbreaker', 4),
#  (1, 'Glory Tracy', 2),
#  (1, 'Go Purple', 3),
#  (1, 'Godfather Diary', 3),
#  (1, 'Gold River', 2),
#  (1, 'Goldfinger Sensibility', 4),
#  (1, 'Goldmine Tycoon', 4),
#  (1, 'Gone Trouble', 2),
#  (1, 'Goodfellas Salute', 4),
#  (1, 'Gorgeous Bingo', 3),
#  (1, 'Gosford Donnie', 3),
#  (1, 'Graceland Dynamite', 2),
#  (1, 'Graduate Lord', 3),
#  (1, 'Graffiti Love', 3),
#  (1, 'Grail Frankenstein', 2),
#  (1, 'Grapes Fury', 4),
#  (1, 'Grease Youth', 3),
#  (1, 'Greatest North', 4),
#  (1, 'Greek Everyone', 2),
#  (1, 'Grinch Massage', 2),
#  (1, 'Grit Clockwork', 4),
#  (1, 'Groove Fiction', 3),
#  (1, 'Groundhog Uncut', 2),
#  (1, 'Gun Bonnie', 3),
#  (1, 'Gunfight Moon', 3),
#  (1, 'Gunfighter Mussolini', 2),
#  (1, 'Guys Falcon', 3),
#  (1, 'Half Outfield', 4),
#  (1, 'Hall Cassidy', 4),
#  (1, 'Halloween Nuts', 2),
#  (1, 'Hamlet Wisdom', 4),
#  (1, 'Handicap Boondock', 3),
#  (1, 'Hanky October', 3),
#  (1, 'Hardly Robbers', 2),
#  (1, 'Harold French', 2),
#  (1, 'Harper Dying', 3),
#  (1, 'Harry Idaho', 4),
#  (1, 'Haunting Pianist', 2),
#  (1, 'Hawk Chill', 2),
#  (1, 'Head Stranger', 4),
#  (1, 'Heartbreakers Bright', 4),
#  (1, 'Heaven Freedom', 3),
#  (1, 'Heavenly Gun', 2),
#  (1, 'Heavyweights Beast', 4),
#  (1, 'Hedwig Alter', 3),
#  (1, 'Hellfighters Sierra', 3),
#  (1, 'High Encino', 3),
#  (1, 'Highball Potter', 2),
#  (1, 'Hills Neighbors', 4),
#  (1, 'Hobbit Alien', 4),
#  (1, 'Holes Brannigan', 2),
#  (1, 'Hollywood Anonymous', 2),
#  (1, 'Holocaust Highball', 3),
#  (1, 'Homeward Cider', 4),
#  (1, 'Homicide Peach', 4),
#  (1, 'Honey Ties', 2),
#  (1, 'Hope Tootsie', 3),
#  (1, 'Horn Working', 4),
#  (1, 'Horror Reign', 4),
#  (1, 'Hotel Happiness', 2),
#  (1, 'Hours Rage', 3),
#  (1, 'House Dynamite', 2),
#  (1, 'Human Graffiti', 2),
#  (1, 'Hunchback Impossible', 4),
#  (1, 'Hunger Roof', 2),
#  (1, 'Hunter Alter', 2),
#  (1, 'Hunting Musketeers', 3),
#  (1, 'Hurricane Affair', 3),
#  (1, 'Hustler Party', 4),
#  (1, 'Hyde Doctor', 3),
#  (1, 'Hysterical Grail', 2),
#  (1, 'Ice Crossing', 4),
#  (1, 'Idaho Love', 2),
#  (1, 'Idols Snatchers', 3),
#  (1, 'Igby Maker', 2),
#  (1, 'Image Princess', 3),
#  (1, 'Impact Aladdin', 2),
#  (1, 'Impossible Prejudice', 4),
#  (1, 'Inch Jet', 2),
#  (1, 'Independence Hotel', 2),
#  (1, 'Indian Love', 2),
#  (1, 'Innocent Usual', 4),
#  (1, 'Insects Stone', 2),
#  (1, 'Insider Arizona', 2),
#  (1, 'Instinct Airport', 3),
#  (1, 'Intentions Empire', 4),
#  (1, 'Interview Liaisons', 2),
#  (1, 'Intolerable Intentions', 2),
#  (1, 'Intrigue Worst', 4),
#  (1, 'Invasion Cyclone', 4),
#  (1, 'Ishtar Rocketeer', 2),
#  (1, 'Island Exorcist', 3),
#  (1, 'Jacket Frisco', 2),
#  (1, 'Jason Trap', 3),
#  (1, 'Jaws Harry', 2),
#  (1, 'Jedi Beneath', 2),
#  (1, 'Jeepers Wedding', 2),
#  (1, 'Jekyll Frogmen', 3),
#  (1, 'Jeopardy Encino', 3),
#  (1, 'Jericho Mulan', 3),
#  (1, 'Jerk Paycheck', 4),
#  (1, 'Jet Neighbors', 4),
#  (1, 'Joon Northwest', 2),
#  (1, 'Juggler Hardly', 4),
#  (1, 'Jumanji Blade', 2),
#  (1, 'Jumping Wrath', 2),
#  (1, 'Jungle Closer', 2),
#  (1, 'Karate Moon', 4),
#  (1, 'Kick Savannah', 2),
#  (1, 'Killer Innocent', 2),
#  (1, 'King Evolution', 2),
#  (1, 'Kiss Glory', 4),
#  (1, 'Kissing Dolls', 3),
#  (1, 'Knock Warlock', 4),
#  (1, 'Kramer Chocolate', 3),
#  (1, 'Kwai Homeward', 4),
#  (1, 'Lady Stage', 4),
#  (1, 'Lawless Vision', 4),
#  (1, 'Lawrence Love', 2),
#  (1, 'League Hellfighters', 2),
#  (1, 'Lebowski Soldiers', 2),
#  (1, 'Liaisons Sweet', 2),
#  (1, 'License Weekend', 2),
#  (1, 'Lies Treatment', 4),
#  (1, 'Lights Deer', 2),
#  (1, 'Lion Uncut', 2),
#  (1, 'Loathing Legally', 4),
#  (1, 'Lola Agent', 2),
#  (1, 'Lolita World', 3),
#  (1, 'Lonely Elephant', 4),
#  (1, 'Lord Arizona', 3),
#  (1, 'Lose Inch', 4),
#  (1, 'Lost Bird', 3),
#  (1, 'Louisiana Harry', 2),
#  (1, 'Love Suicides', 4),
#  (1, 'Lovely Jingle', 3),
#  (1, 'Luck Opus', 2),
#  (1, 'Lucky Flying', 3),
#  (1, 'Lust Lock', 4),
#  (1, 'Madigan Dorado', 2),
#  (1, 'Madison Trap', 2),
#  (1, 'Madness Attacks', 4),
#  (1, 'Magnificent Chitty', 2),
#  (1, 'Magnolia Forrester', 2),
#  (1, 'Maguire Apache', 3),
#  (1, 'Maiden Home', 3),
#  (1, 'Malkovich Pet', 4),
#  (1, 'Mallrats United', 3),
#  (1, 'Maltese Hope', 3),
#  (1, 'Manchurian Curtain', 2),
#  (1, 'Married Go', 4),
#  (1, 'Mars Roman', 3),
#  (1, 'Mask Peach', 4),
#  (1, 'Masked Bubble', 4),
#  (1, 'Massacre Usual', 4),
#  (1, 'Matrix Snowman', 2),
#  (1, 'Maude Mod', 2),
#  (1, 'Meet Chocolate', 2),
#  (1, 'Memento Zoolander', 2),
#  (1, 'Menagerie Rushmore', 2),
#  (1, 'Mermaid Insects', 2),
#  (1, 'Metal Armageddon', 2),
#  (1, 'Metropolis Coma', 4),
#  (1, 'Microcosmos Paradise', 4),
#  (1, 'Midnight Westward', 2),
#  (1, 'Midsummer Groundhog', 2),
#  (1, 'Mile Mulan', 3),
#  (1, 'Million Ace', 2),
#  (1, 'Minds Truman', 4),
#  (1, 'Mine Titans', 4),
#  (1, 'Minority Kiss', 3),
#  (1, 'Mission Zoolander', 3),
#  (1, 'Mixed Doors', 2),
#  (1, 'Mockingbird Hollywood', 4),
#  (1, 'Mod Secretary', 3),
#  (1, 'Money Harold', 3),
#  (1, 'Monster Spartacus', 2),
#  (1, 'Montezuma Command', 3),
#  (1, 'Moon Bunch', 4),
#  (1, 'Moonshine Cabin', 2),
#  (1, 'Mosquito Armageddon', 4),
#  (1, 'Mother Oleander', 3),
#  (1, 'Motions Details', 2),
#  (1, 'Moulin Wake', 3),
#  (1, 'Mourning Purple', 2),
#  (1, 'Movie Shakespeare', 4),
#  (1, 'Mummy Creatures', 2),
#  (1, 'Murder Antitrust', 2),
#  (1, 'Muscle Bright', 4),
#  (1, 'Music Boondock', 2),
#  (1, 'Musketeers Wait', 4),
#  (1, 'Mystic Truman', 2),
#  (1, 'Name Detective', 3),
#  (1, 'National Story', 2),
#  (1, 'Natural Stock', 3),
#  (1, 'Neighbors Charade', 2),
#  (1, 'Nemo Campus', 2),
#  (1, 'Network Peak', 4),
#  (1, 'Newton Labyrinth', 2),
#  (1, 'Nightmare Chill', 3),
#  (1, 'None Spiking', 3),
#  (1, 'Northwest Polish', 3),
#  (1, 'Novocaine Flight', 3),
#  (1, 'Nuts Ties', 3),
#  (1, 'Oleander Clue', 3),
#  (1, 'Open African', 2),
#  (1, 'Operation Operation', 4),
#  (1, 'Orange Grapes', 3),
#  (1, 'Orient Closer', 3),
#  (1, 'Oscar Gold', 3),
#  (1, 'Others Soup', 3),
#  (1, 'Outbreak Divine', 3),
#  (1, 'Outfield Massacre', 3),
#  (1, 'Outlaw Hanky', 4),
#  (1, 'Oz Liaisons', 2),
#  (1, 'Pacific Amistad', 2),
#  (1, 'Packer Madigan', 2),
#  (1, 'Pajama Jawbreaker', 4),
#  (1, 'Panic Club', 2),
#  (1, 'Panky Submarine', 2),
#  (1, 'Panther Reds', 3),
#  (1, 'Paradise Sabrina', 4),
#  (1, 'Party Knock', 2),
#  (1, 'Past Suicides', 4),
#  (1, 'Paths Control', 2),
#  (1, 'Patient Sister', 3),
#  (1, 'Patriot Roman', 2),
#  (1, 'Patton Interview', 4),
#  (1, 'Paycheck Wait', 3),
#  (1, 'Peach Innocent', 2),
#  (1, 'Peak Forever', 2),
#  (1, 'Pelican Comforts', 4),
#  (1, 'Perfect Groove', 2),
#  (1, 'Personal Ladybugs', 2),
#  (1, 'Pet Haunting', 3),
#  (1, 'Phantom Glory', 2),
#  (1, 'Philadelphia Wife', 2),
#  (1, 'Pianist Outfield', 3),
#  (1, 'Pickup Driving', 4),
#  (1, 'Pilot Hoosiers', 2),
#  (1, 'Pinocchio Simon', 2),
#  (1, 'Pirates Roxanne', 3),
#  (1, 'Pittsburgh Hunchback', 3),
#  (1, 'Pity Bound', 4),
#  (1, 'Pluto Oleander', 4),
#  (1, 'Pocus Pulp', 3),
#  (1, 'Pollock Deliverance', 4),
#  (1, 'Pond Seattle', 4),
#  (1, 'Poseidon Forever', 3),
#  (1, 'Potter Connecticut', 2),
#  (1, 'Prejudice Oleander', 4),
#  (1, 'President Bang', 2),
#  (1, 'Pride Alamo', 2),
#  (1, 'Primary Glass', 4),
#  (1, 'Princess Giant', 4),
#  (1, 'Private Drop', 2),
#  (1, 'Pulp Beverly', 4),
#  (1, 'Pure Runner', 2),
#  (1, 'Purple Movie', 4),
#  (1, 'Queen Luke', 2),
#  (1, 'Quest Mussolini', 2),
#  (1, 'Quills Bull', 2),
#  (1, 'Racer Egg', 2),
#  (1, 'Rage Games', 4),
#  (1, 'Range Moonwalker', 4),
#  (1, 'Reap Unfaithful', 2),
#  (1, 'Rear Trading', 2),
#  (1, 'Records Zorro', 2),
#  (1, 'Redemption Comforts', 3),
#  (1, 'Reds Pocus', 2),
#  (1, 'Reef Salute', 2),
#  (1, 'Reign Gentlemen', 4),
#  (1, 'Remember Diary', 2),
#  (1, 'Requiem Tycoon', 3),
#  (1, 'Resurrection Silverado', 2),
#  (1, 'Reunion Witches', 3),
#  (1, 'Ridgemont Submarine', 4),
#  (1, 'Rings Heartbreakers', 4),
#  (1, 'River Outlaw', 4),
#  (1, 'Road Roxanne', 2),
#  (1, 'Robbers Joon', 3),
#  (1, 'Robbery Bright', 4),
#  (1, 'Rock Instinct', 2),
#  (1, 'Rocketeer Mother', 4),
#  (1, 'Rocky War', 2),
#  (1, 'Roman Punk', 4),
#  (1, 'Room Roman', 2),
#  (1, 'Roots Remember', 2),
#  (1, 'Roses Treasure', 4),
#  (1, 'Rouge Squad', 2),
#  (1, 'Roxanne Rebel', 2),
#  (1, 'Rugrats Shakespeare', 4),
#  (1, 'Rules Human', 2),
#  (1, 'Run Pacific', 3),
#  (1, 'Rush Goodfellas', 4),
#  (1, 'Sabrina Midnight', 4),
#  (1, 'Sagebrush Clueless', 3),
#  (1, 'Salute Apollo', 2),
#  (1, 'Samurai Lion', 3),
#  (1, 'Satisfaction Confidential', 3),
#  (1, 'Saturday Lambs', 4),
#  (1, 'Saturn Name', 4),
#  (1, 'Savannah Town', 3),
#  (1, 'Scalawag Duck', 4),
#  (1, 'Scarface Bang', 3),
#  (1, 'Scorpion Apollo', 3),
#  (1, 'Sea Virgin', 4),
#  (1, 'Seabiscuit Punk', 4),
#  (1, 'Searchers Wait', 4),
#  (1, 'Seattle Expecations', 3),
#  (1, 'Secret Groundhog', 2),
#  (1, 'Secretary Rouge', 3),
#  (1, 'Secrets Paradise', 4),
#  (1, 'Shakespeare Saddle', 3),
#  (1, 'Shane Darkness', 4),
#  (1, 'Shanghai Tycoon', 3),
#  (1, 'Shawshank Bubble', 4),
#  (1, 'Shepherd Midsummer', 3),
#  (1, 'Shining Roses', 3),
#  (1, 'Ship Wonderland', 2),
#  (1, 'Shock Cabin', 4),
#  (1, 'Shootist Superfly', 4),
#  (1, 'Show Lord', 2),
#  (1, 'Shrunk Divine', 4),
#  (1, 'Side Ark', 2),
#  (1, 'Siege Madre', 4),
#  (1, 'Sierra Divide', 2),
#  (1, 'Silence Kane', 2),
#  (1, 'Silverado Goldfinger', 2),
#  (1, 'Simon North', 2),
#  (1, 'Sinners Atlantis', 2),
#  (1, 'Slacker Liaisons', 4),
#  (1, 'Sleeping Suspects', 4),
#  (1, 'Sleepless Monsoon', 2),
#  (1, 'Sleepy Japanese', 3),
#  (1, 'Sleuth Orient', 3),
#  (1, 'Slums Duck', 4),
#  (1, 'Smile Earring', 3),
#  (1, 'Smoking Barbarella', 3),
#  (1, 'Snatch Slipper', 3),
#  (1, 'Snatchers Montezuma', 3),
#  (1, 'Snowman Rollercoaster', 4),
#  (1, 'Soldiers Evolution', 2),
#  (1, 'Something Duck', 3),
#  (1, 'Song Hedwig', 3),
#  (1, 'Sons Interview', 4),
#  (1, 'South Wait', 3),
#  (1, 'Speakeasy Date', 3),
#  (1, 'Spice Sorority', 2),
#  (1, 'Spinal Rocky', 2),
#  (1, 'Spirited Casualties', 3),
#  (1, 'Splash Gump', 4),
#  (1, 'Splendor Patton', 3),
#  (1, 'Spy Mile', 4),
#  (1, 'Squad Fish', 3),
#  (1, 'Stagecoach Armageddon', 2),
#  (1, 'Stampede Disturbing', 4),
#  (1, 'Star Operation', 3),
#  (1, 'State Wasteland', 2),
#  (1, 'Steel Santa', 4),
#  (1, 'Steers Armageddon', 2),
#  (1, 'Stepmom Dream', 4),
#  (1, 'Sting Personal', 4),
#  (1, 'Stone Fire', 3),
#  (1, 'Storm Happiness', 4),
#  (1, 'Story Side', 3),
#  (1, 'Straight Hours', 3),
#  (1, 'Strangelove Desire', 4),
#  (1, 'Stranger Strangers', 3),
#  (1, 'Streak Ridgemont', 2),
#  (1, 'Streetcar Intentions', 4),
#  (1, 'Strictly Scarface', 3),
#  (1, 'Sugar Wonka', 3),
#  (1, 'Suit Walls', 3),
#  (1, 'Summer Scarface', 3),
#  (1, 'Sun Confessions', 4),
#  (1, 'Sundance Invasion', 4),
#  (1, 'Sunrise League', 4),
#  (1, 'Super Wyoming', 4),
#  (1, 'Superfly Trip', 3),
#  (1, 'Suspects Quills', 4),
#  (1, 'Swarm Gold', 4),
#  (1, 'Sweden Shining', 2),
#  (1, 'Sweethearts Suspects', 4),
#  (1, 'Talented Homicide', 3),
#  (1, 'Tarzan Videotape', 2),
#  (1, 'Taxi Kick', 3),
#  (1, 'Telegraph Voyage', 4),
#  (1, 'Telemark Heartbreakers', 4),
#  (1, 'Tenenbaums Command', 4),
#  (1, 'Texas Watch', 2),
#  (1, 'Theory Mermaid', 4),
#  (1, 'Thief Pelican', 4),
#  (1, 'Thin Sagebrush', 4),
#  (1, 'Ties Hunger', 3),
#  (1, 'Tights Dawn', 3),
#  (1, 'Timberland Sky', 3),
#  (1, 'Titanic Boondock', 3),
#  (1, 'Titans Jerk', 4),
#  (1, 'Tomatoes Hellfighters', 3),
#  (1, 'Tomorrow Hustler', 4),
#  (1, 'Tootsie Pilot', 2),
#  (1, 'Torque Bound', 4),
#  (1, 'Tourist Pelican', 3),
#  (1, 'Towers Hurricane', 3),
#  (1, 'Town Ark', 2),
#  (1, 'Tracy Cider', 4),
#  (1, 'Trading Pinocchio', 4),
#  (1, 'Train Bunch', 2),
#  (1, 'Trainspotting Strangers', 3),
#  (1, 'Tramp Others', 2),
#  (1, 'Translation Summer', 4),
#  (1, 'Trap Guys', 2),
#  (1, 'Trip Newton', 4),
#  (1, 'Trojan Tomorrow', 3),
#  (1, 'Troopers Metal', 4),
#  (1, 'Trouble Date', 2),
#  (1, 'Truman Crazy', 4),
#  (1, 'Turn Star', 2),
#  (1, 'Tuxedo Mile', 3),
#  (1, 'Tycoon Gathering', 4),
#  (1, 'Unbreakable Karate', 3),
#  (1, 'Uncut Suicides', 2),
#  (1, 'Undefeated Dalmations', 3),
#  (1, 'Unforgiven Zoolander', 2),
#  (1, 'United Pilot', 3),
#  (1, 'Uprising Uptown', 4),
#  (1, 'Uptown Young', 3),
#  (1, 'Usual Untouchables', 4),
#  (1, 'Vacation Boondock', 3),
#  (1, 'Valley Packer', 2),
#  (1, 'Vampire Whale', 3),
#  (1, 'Vanishing Rocky', 2),
#  (1, 'Varsity Trip', 2),
#  (1, 'Velvet Terminator', 4),
#  (1, 'Victory Academy', 3),
#  (1, 'Videotape Arsenic', 4),
#  (1, 'Vietnam Smoochy', 2),
#  (1, 'Virgin Daisy', 2),
#  (1, 'Virginian Pluto', 4),
#  (1, 'Vision Torque', 2),
#  (1, 'Voice Peach', 2),
#  (1, 'Volcano Texas', 4),
#  (1, 'Voyage Legally', 3),
#  (1, 'Wagon Jaws', 3),
#  (1, 'Wait Cider', 4),
#  (1, 'Wanda Chamber', 4),
#  (1, 'War Notting', 3),
#  (1, 'Wardrobe Phantom', 3),
#  (1, 'Warlock Werewolf', 2),
#  (1, 'Wash Heavenly', 3),
#  (1, 'Wasteland Divine', 4),
#  (1, 'Watch Tracy', 2),
#  (1, 'Waterfront Deliverance', 3),
#  (1, 'Watership Frontier', 2),
#  (1, 'Wedding Apollo', 2),
#  (1, 'Weekend Personal', 3),
#  (1, 'Werewolf Lola', 3),
#  (1, 'West Lion', 4),
#  (1, 'Westward Seabiscuit', 3),
#  (1, 'Whale Bikini', 4),
#  (1, 'Whisperer Giant', 3),
#  (1, 'Wife Turn', 4),
#  (1, 'Wild Apollo', 2),
#  (1, 'Willow Tracy', 2),
#  (1, 'Wind Phantom', 2),
#  (1, 'Wisdom Worker', 3),
#  (1, 'Witches Panic', 4),
#  (1, 'Wizard Coldblooded', 3),
#  (1, 'Wolves Desire', 3),
#  (1, 'Women Dorado', 3),
#  (1, 'Won Dares', 3),
#  (1, 'Wonderful Drop', 2),
#  (1, 'Wonderland Christmas', 4),
#  (1, 'Wonka Sea', 4),
#  (1, 'Words Hunter', 2),
#  (1, 'Worker Tarzan', 3),
#  (1, 'Working Microcosmos', 4),
#  (1, 'Worst Banger', 2),
#  (1, 'Wrong Behavior', 4),
#  (1, 'Wyoming Storm', 3),
#  (1, 'Yentl Idaho', 4),
#  (1, 'Young Language', 2),
#  (1, 'Youth Kick', 2),
#  (1, 'Zoolander Fiction', 2),
#  (1, 'Zorro Ark', 4),
#  (2, 'Academy Dinosaur', 4),
#  (2, 'Ace Goldfinger', 3),
#  (2, 'Adaptation Holes', 4),
#  (2, 'Affair Prejudice', 3),
#  (2, 'African Egg', 3),
#  (2, 'Agent Truman', 3),
#  (2, 'Airplane Sierra', 3),
#  (2, 'Airport Pollock', 4),
#  (2, 'Alabama Devil', 2),
#  (2, 'Aladdin Calendar', 3),
#  (2, 'Alamo Videotape', 3),
#  (2, 'Alaska Phantom', 4),
#  (2, 'Ali Forever', 4),
#  (2, 'Alien Center', 4),
#  (2, 'Alley Evolution', 2),
#  (2, 'Alone Trip', 3),
#  (2, 'Alter Victory', 3),
#  (2, 'Amadeus Holy', 2),
#  (2, 'American Circus', 4),
#  (2, 'Amistad Midsummer', 3),
#  (2, 'Anaconda Confessions', 2),
#  (2, 'Angels Life', 2),
#  (2, 'Annie Identity', 3),
#  (2, 'Apache Divine', 4),
#  (2, 'Apocalypse Flamingos', 2),
#  (2, 'Arabia Dogma', 4),
#  (2, 'Arachnophobia Rollercoaster', 3),
#  (2, 'Arizona Bang', 3),
#  (2, 'Armageddon Lost', 4),
#  (2, 'Army Flintstones', 4),
#  (2, 'Artist Coldblooded', 4),
#  (2, 'Atlantis Cause', 4),
#  (2, 'Attacks Hate', 3),
#  (2, 'Attraction Newton', 2),
#  (2, 'Autumn Crow', 3),
#  (2, 'Baby Hall', 2),
#  (2, 'Backlash Undefeated', 2),
#  (2, 'Badman Dawn', 3),
#  (2, 'Baked Cleopatra', 2),
#  (2, 'Balloon Homeward', 4),
#  (2, 'Ballroom Mockingbird', 2),
#  (2, 'Banger Pinocchio', 2),
#  (2, 'Barbarella Streetcar', 2),
#  (2, 'Barefoot Manchurian', 2),
#  (2, 'Basic Easy', 3),
#  (2, 'Beach Heartbreakers', 4),
#  (2, 'Bear Graceland', 2),
#  (2, 'Beauty Grease', 2),
#  (2, 'Bed Highball', 2),
#  (2, 'Bedazzled Married', 2),
#  (2, 'Beethoven Exorcist', 3),
#  (2, 'Behavior Runaway', 4),
#  (2, 'Berets Agent', 4),
#  (2, 'Betrayed Rear', 2),
#  (2, 'Beverly Outlaw', 4),
#  (2, 'Bikini Borrowers', 2),
#  (2, 'Bilko Anonymous', 4),
#  (2, 'Bill Others', 2),
#  (2, 'Bingo Talented', 4),
#  (2, 'Birch Antitrust', 2),
#  (2, 'Bird Independence', 3),
#  (2, 'Birds Perdition', 2),
#  (2, 'Blackout Private', 4),
#  (2, 'Blade Polish', 3),
#  (2, 'Blues Instinct', 2),
#  (2, 'Bonnie Holocaust', 4),
#  (2, 'Boogie Amelie', 4),
#  (2, 'Born Spinal', 4),
#  (2, 'Borrowers Bedazzled', 3),
#  (2, 'Boulevard Mob', 3),
#  (2, 'Bound Cheaper', 4),
#  (2, 'Bowfinger Gables', 2),
#  (2, 'Brannigan Sunrise', 3),
#  (2, 'Breakfast Goldfinger', 3),
#  (2, 'Bride Intrigue', 2),
#  (2, 'Bringing Hysterical', 3),
#  (2, 'Brooklyn Desert', 2),
#  (2, 'Brotherhood Blanket', 2),
#  (2, 'Bubble Grosse', 2),
#  (2, 'Bucket Brotherhood', 4),
#  (2, 'Bugsy Song', 3),
#  (2, 'Bull Shawshank', 3),
#  (2, 'Bunch Minds', 2),
#  (2, 'Butterfly Chocolat', 4),
#  (2, 'Caddyshack Jedi', 4),
#  (2, 'Calendar Gunfight', 3),
#  (2, 'California Birds', 4),
#  (2, 'Camelot Vacation', 3),
#  (2, 'Campus Remember', 4),
#  (2, 'Candidate Perdition', 4),
#  (2, 'Candles Grapes', 2),
#  (2, 'Canyon Stock', 2),
#  (2, 'Caper Motions', 4),
#  (2, 'Carol Texas', 3),
#  (2, 'Carrie Bunch', 3),
#  (2, 'Casablanca Super', 3),
#  (2, 'Casper Dragonfly', 3),
#  (2, 'Cassidy Wyoming', 2),
#  (2, 'Casualties Encino', 3),
#  (2, 'Cat Coneheads', 4),
#  (2, 'Cause Date', 3),
#  (2, 'Celebrity Horn', 4),
#  (2, 'Center Dinosaur', 2),
#  (2, 'Chainsaw Uptown', 2),
#  (2, 'Chamber Italian', 2),
#  (2, 'Champion Flatliners', 3),
#  (2, 'Chance Resurrection', 4),
#  (2, 'Charade Duffel', 4),
#  (2, 'Chariots Conspiracy', 3),
#  (2, 'Chasing Fight', 2),
#  (2, 'Cheaper Clyde', 3),
#  (2, 'Chicago North', 2),
#  (2, 'Chicken Hellfighters', 2),
#  (2, 'Chill Luck', 3),
#  (2, 'Chisum Behavior', 3),
#  (2, 'Chocolat Harry', 3),
#  (2, 'Christmas Moonshine', 3),
#  (2, 'Cider Desire', 4),
#  (2, 'Cincinatti Whisperer', 2),
#  (2, 'Clash Freddy', 4),
#  (2, 'Cleopatra Devil', 3),
#  (2, 'Clerks Angels', 2),
#  (2, 'Clockwork Paradise', 3),
#  (2, 'Clones Pinocchio', 3),
#  (2, 'Closer Bang', 3),
#  (2, 'Club Graffiti', 3),
#  (2, 'Clueless Bucket', 4),
#  (2, 'Clyde Theory', 3),
#  (2, 'Coast Rainbow', 3),
#  (2, 'Coldblooded Darling', 2),
#  (2, 'Color Philadelphia', 2),
#  (2, 'Coma Head', 3),
#  (2, 'Comforts Rush', 2),
#  (2, 'Command Darling', 4),
#  (2, 'Coneheads Smoochy', 3),
#  (2, 'Confessions Maguire', 2),
#  (2, 'Confidential Interview', 4),
#  (2, 'Confused Candles', 3),
#  (2, 'Congeniality Quest', 4),
#  (2, 'Connecticut Tramp', 3),
#  (2, 'Conspiracy Spirit', 2),
#  (2, 'Contact Anonymous', 4),
#  (2, 'Conversation Downhill', 3),
#  (2, 'Core Suit', 3),
#  (2, 'Craft Outfield', 2),
#  (2, 'Cranes Reservoir', 3),
#  (2, 'Creatures Shakespeare', 4),
#  (2, 'Creepers Kane', 4),
#  (2, 'Crooked Frogmen', 3),
#  (2, 'Crossroads Casualties', 4),
#  (2, 'Crow Grease', 2),
#  (2, 'Cupboard Sinners', 4),
#  (2, 'Curtain Videotape', 4),
#  (2, 'Daisy Menagerie', 4),
#  (2, 'Dalmations Sweden', 2),
#  (2, 'Dancing Fever', 4),
#  (2, 'Darko Dorado', 3),
#  (2, 'Darn Forrester', 2),
#  (2, 'Daughter Madigan', 4),
#  (2, 'Dawn Pond', 3),
#  (2, 'Day Unfaithful', 3),
#  (2, 'Deceiver Betrayed', 3),
#  (2, 'Deer Virginian', 4),
#  (2, 'Desert Poseidon', 4),
#  (2, 'Desire Alien', 2),
#  (2, 'Destiny Saturday', 3),
#  (2, 'Details Packer', 2),
#  (2, 'Detective Vision', 4),
#  (2, 'Devil Desire', 2),
#  (2, 'Dinosaur Secretary', 4),
#  (2, 'Dirty Ace', 2),
#  (2, 'Disciple Mother', 2),
#  (2, 'Disturbing Scarface', 3),
#  (2, 'Divide Monster', 4),
#  (2, 'Divine Resurrection', 4),
#  (2, 'Dogma Family', 4),
#  (2, 'Dolls Rage', 3),
#  (2, 'Doom Dancing', 3),
#  (2, 'Doors President', 4),
#  (2, 'Dorado Notting', 3),
#  (2, 'Double Wrath', 4),
#  (2, 'Doubtfire Labyrinth', 3),
#  (2, 'Downhill Enough', 4),
#  (2, 'Dozen Lion', 2),
#  (2, 'Dracula Crystal', 4),
#  (2, 'Dragon Squad', 4),
#  (2, 'Dragonfly Strangers', 3),
#  (2, 'Dream Pickup', 3),
#  (2, 'Drifter Commandments', 2),
#  (2, 'Driver Annie', 3),
#  (2, 'Driving Polish', 2),
#  (2, 'Drop Waterfront', 3),
#  (2, 'Drumline Cyclone', 3),
#  (2, 'Drums Dynamite', 4),
#  (2, 'Dude Blindness', 4),
#  (2, 'Dumbo Lust', 2),
#  (2, 'Durham Panky', 3),
#  (2, 'Dwarfs Alter', 2),
#  (2, 'Dynamite Tarzan', 4),
#  (2, 'Eagles Panky', 2),
#  (2, 'Early Home', 2),
#  (2, 'Earring Instinct', 4),
#  (2, 'Earth Vision', 4),
#  (2, 'Easy Gladiator', 2),
#  (2, 'Effect Gladiator', 3),
#  (2, 'Egg Igby', 4),
#  (2, 'Egypt Tenenbaums', 2),
#  (2, 'Empire Malkovich', 2),
#  (2, 'Encino Elf', 4),
#  (2, 'Encounters Curtain', 3),
#  (2, 'Enemy Odds', 4),
#  (2, 'English Bulworth', 4),
#  (2, 'Enough Raging', 3),
#  (2, 'Entrapment Satisfaction', 2),
#  (2, 'Escape Metropolis', 4),
#  (2, 'Excitement Eve', 3),
#  (2, 'Exorcist Sting', 3),
#  (2, 'Expecations Natural', 3),
#  (2, 'Expendable Stallion', 4),
#  (2, 'Extraordinary Conquerer', 2),
#  (2, 'Eyes Driving', 3),
#  (2, 'Falcon Volume', 4),
#  (2, 'Family Sweet', 4),
#  (2, 'Fantasia Park', 4),
#  (2, 'Fantasy Troopers', 2),
#  (2, 'Fargo Gandhi', 2),
#  (2, 'Fatal Haunted', 3),
#  (2, 'Fellowship Autumn', 3),
#  (2, 'Ferris Mother', 2),
#  (2, 'Feud Frogmen', 4),
#  (2, 'Fiction Christmas', 4),
#  (2, 'Fiddler Lost', 3),
#  (2, 'Fidelity Devil', 2),
#  (2, 'Fight Jawbreaker', 4),
#  (2, 'Finding Anaconda', 3),
#  (2, 'Fire Wolves', 2),
#  (2, 'Fireball Philadelphia', 3),
#  (2, 'Fish Opus', 4),
#  (2, 'Flamingos Connecticut', 4),
#  (2, 'Flatliners Killer', 2),
#  (2, 'Flight Lies', 4),
#  ...]

# %% [markdown]
# ## Question 7
# Customer name and email who eligible for the platinum credit card (transaction payment >= 40)

# %%
# %%sql
#
# SELECT concat(c.first_name,' ', c.last_name) as fullname, c.email, count(p.payment_id) as transaction_payment
#     FROM customer c
#     INNER JOIN payment p
#     ON c.customer_id = p.customer_id
#     GROUP BY c.customer_id
#     HAVING count(p.payment_id) >= 40
#     ORDER BY count(p.payment_id) desc;
# Out:
#  * postgresql://postgres:***@localhost/DVDrental
# 3 rows affected.
# [('Eleanor Hunt', 'eleanor.hunt@sakilacustomer.org', 45),
#  ('Karl Seal', 'karl.seal@sakilacustomer.org', 42),
#  ('Clara Shaw', 'clara.shaw@sakilacustomer.org', 40)]
